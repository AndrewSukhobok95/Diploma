# %%
from funcs import *
% matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Data

# %%
df = pd.read_excel('serieses.xlsx')

# %% [markdown]
# ---

# %% [markdown]
# # Government consumption expenditures and gross investment

# %%
gov_consump_inv = df.iloc[32, 1:186].copy()
gov_consump_inv.index = pd.DatetimeIndex(start='1969-01', end='2015-04', freq='Q')

# %%
ind = gov_consump_inv.index
gov_consump_inv = pd.Series([np.log(i) for i in gov_consump_inv.tolist()], index=ind)

# %%
test_stationarity(gov_consump_inv)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.817864
# p-value                          0.055767
# #Lags Used                       4.000000
# Number of Observations Used    180.000000
# Critical Value (1%)             -3.467211
# Critical Value (10%)            -2.575403
# Critical Value (5%)             -2.877735
# dtype: float64
#
#
# Results of KPSS Test:
# Test Statistic            1.302884
# p-value                   0.010000
# #Lags Used               14.000000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# dtype: float64
# /home/andrey/anaconda3/envs/neural_net/lib/python3.5/site-packages/statsmodels/tsa/stattools.py:1258: InterpolationWarning: p-value is smaller than the indicated p-value
#   warn("p-value is smaller than the indicated p-value", InterpolationWarning)

# %%
test_stationarity(diff_series(gov_consump_inv))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.622798
# p-value                          0.088376
# #Lags Used                       3.000000
# Number of Observations Used    180.000000
# Critical Value (1%)             -3.467211
# Critical Value (10%)            -2.575403
# Critical Value (5%)             -2.877735
# dtype: float64
#
#
# Results of KPSS Test:
# Test Statistic            0.737372
# p-value                   0.010148
# #Lags Used               14.000000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# dtype: float64

# %%
test_stationarity(diff_series(diff_series(gov_consump_inv)))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.159511e+01
# p-value                        2.732366e-21
# #Lags Used                     3.000000e+00
# Number of Observations Used    1.790000e+02
# Critical Value (1%)           -3.467420e+00
# Critical Value (10%)          -2.575452e+00
# Critical Value (5%)           -2.877826e+00
# dtype: float64
#
#
# Results of KPSS Test:
# Test Statistic            0.0963
# p-value                   0.1000
# #Lags Used               14.0000
# Critical Value (2.5%)     0.5740
# Critical Value (1%)       0.7390
# Critical Value (10%)      0.3470
# Critical Value (5%)       0.4630
# dtype: float64
# /home/andrey/anaconda3/envs/neural_net/lib/python3.5/site-packages/statsmodels/tsa/stattools.py:1260: InterpolationWarning: p-value is greater than the indicated p-value
#   warn("p-value is greater than the indicated p-value", InterpolationWarning)

# %%
train = gov_consump_inv[:-8]
test = gov_consump_inv[-8:]

# %% [markdown]
# ### ARIMA

# %%
correlogram(diff_series(train))

# %%
arima_model = ARIMA(np.array(train), order=(3,1,1)).fit(trend='nc')
print(arima_model.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                  176
# Model:                 ARIMA(3, 1, 1)   Log Likelihood                 572.881
# Method:                       css-mle   S.D. of innovations              0.009
# Date:                Tue, 09 May 2017   AIC                          -1135.761
# Time:                        04:22:42   BIC                          -1119.909
# Sample:                             1   HQIC                         -1129.332
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1.D.y      0.8356      0.110      7.618      0.000       0.621       1.051
# ar.L2.D.y     -0.0844      0.098     -0.860      0.391      -0.277       0.108
# ar.L3.D.y      0.2351      0.093      2.517      0.013       0.052       0.418
# ma.L1.D.y     -0.6991      0.097     -7.222      0.000      -0.889      -0.509
#                                     Roots
# =============================================================================
#                  Real           Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0099           -0.0000j            1.0099           -0.0000
# AR.2           -0.3255           -2.0262j            2.0521           -0.2754
# AR.3           -0.3255           +2.0262j            2.0521            0.2754
# MA.1            1.4305           +0.0000j            1.4305            0.0000
# -----------------------------------------------------------------------------

# %%
arima_model.plot_predict()
plt.show()

# %%
forc_arima = arima_model.forecast(len(test))
plot_forecast_out_only(test, forc_arima, bbox_loc=(1.03,1))

# %%
errors_out_sample(test, forc_arima[0])
# Out:
# {'MAE': 0.014026671561956805,
#  'MSE': 0.00030845064246102182,
#  'RMSE': 0.017562762950658471}

# %% [markdown]
# ### ANN

# %% [markdown]
# #### First launch

# %%
scaled_train = scaler(train)[0]

# %%
lags_for_nn = 2

train_nn = create_df_for_nn(scaled_train, lags_for_nn)

# %%
def assemble_model(n_lags):
    model = Sequential()
    # Layers
    model.add(Dense(10, input_dim=n_lags, activation='sigmoid'))
    model.add(Dense(10, input_dim=10, activation='sigmoid'))
    #model.add(Dense(10, input_dim=10, activation='sigmoid'))
    model.add(Dense(1, input_dim=10))
    # Compilation
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

nn = assemble_model(lags_for_nn)
nn.fit(np.array(train_nn.iloc[:, :-1]), 
       np.array(train_nn.iloc[:, -1]), 
       nb_epoch=100, 
       verbose=2,
       batch_size=1)
# Out:
# Epoch 1/100
# 0s - loss: 0.0710
# Epoch 2/100
# 0s - loss: 0.0568
# Epoch 3/100
# 0s - loss: 0.0430
# Epoch 4/100
# 0s - loss: 0.0295
# Epoch 5/100
# 0s - loss: 0.0164
# Epoch 6/100
# 0s - loss: 0.0071
# Epoch 7/100
# 0s - loss: 0.0025
# Epoch 8/100
# 0s - loss: 6.6208e-04
# Epoch 9/100
# 0s - loss: 2.2871e-04
# Epoch 10/100
# 0s - loss: 1.5826e-04
# Epoch 11/100
# 0s - loss: 1.5253e-04
# Epoch 12/100
# 0s - loss: 1.5821e-04
# Epoch 13/100
# 0s - loss: 1.5516e-04
# Epoch 14/100
# 0s - loss: 1.6406e-04
# Epoch 15/100
# 0s - loss: 1.5076e-04
# Epoch 16/100
# 0s - loss: 1.5337e-04
# Epoch 17/100
# 0s - loss: 1.6759e-04
# Epoch 18/100
# 0s - loss: 1.6584e-04
# Epoch 19/100
# 0s - loss: 1.6166e-04
# Epoch 20/100
# 0s - loss: 1.4052e-04
# Epoch 21/100
# 0s - loss: 1.5391e-04
# Epoch 22/100
# 0s - loss: 1.7568e-04
# Epoch 23/100
# 0s - loss: 1.6955e-04
# Epoch 24/100
# 0s - loss: 1.5914e-04
# Epoch 25/100
# 0s - loss: 1.5879e-04
# Epoch 26/100
# 0s - loss: 1.4835e-04
# Epoch 27/100
# 0s - loss: 1.5321e-04
# Epoch 28/100
# 0s - loss: 1.6108e-04
# Epoch 29/100
# 0s - loss: 1.5082e-04
# Epoch 30/100
# 0s - loss: 1.5056e-04
# Epoch 31/100
# 0s - loss: 1.5077e-04
# Epoch 32/100
# 0s - loss: 1.7406e-04
# Epoch 33/100
# 0s - loss: 1.6347e-04
# Epoch 34/100
# 0s - loss: 1.4919e-04
# Epoch 35/100
# 0s - loss: 1.7147e-04
# Epoch 36/100
# 0s - loss: 1.6647e-04
# Epoch 37/100
# 0s - loss: 1.5454e-04
# Epoch 38/100
# 0s - loss: 1.6947e-04
# Epoch 39/100
# 0s - loss: 1.5686e-04
# Epoch 40/100
# 0s - loss: 1.7979e-04
# Epoch 41/100
# 0s - loss: 1.5100e-04
# Epoch 42/100
# 0s - loss: 1.3819e-04
# Epoch 43/100
# 0s - loss: 1.7246e-04
# Epoch 44/100
# 0s - loss: 1.4907e-04
# Epoch 45/100
# 0s - loss: 2.3134e-04
# Epoch 46/100
# 0s - loss: 1.5084e-04
# Epoch 47/100
# 0s - loss: 1.4372e-04
# Epoch 48/100
# 0s - loss: 1.2665e-04
# Epoch 49/100
# 0s - loss: 1.7275e-04
# Epoch 50/100
# 0s - loss: 1.3081e-04
# Epoch 51/100
# 0s - loss: 1.4622e-04
# Epoch 52/100
# 0s - loss: 1.4006e-04
# Epoch 53/100
# 0s - loss: 1.6830e-04
# Epoch 54/100
# 0s - loss: 1.5355e-04
# Epoch 55/100
# 0s - loss: 1.4324e-04
# Epoch 56/100
# 0s - loss: 1.3925e-04
# Epoch 57/100
# 0s - loss: 1.4406e-04
# Epoch 58/100
# 0s - loss: 1.3971e-04
# Epoch 59/100
# 0s - loss: 1.6548e-04
# Epoch 60/100
# 0s - loss: 1.4686e-04
# Epoch 61/100
# 0s - loss: 1.5897e-04
# Epoch 62/100
# 0s - loss: 1.7410e-04
# Epoch 63/100
# 0s - loss: 1.3601e-04
# Epoch 64/100
# 0s - loss: 1.2995e-04
# Epoch 65/100
# 0s - loss: 1.4347e-04
# Epoch 66/100
# 0s - loss: 1.2314e-04
# Epoch 67/100
# 0s - loss: 1.0956e-04
# Epoch 68/100
# 0s - loss: 1.4852e-04
# Epoch 69/100
# 0s - loss: 1.1483e-04
# Epoch 70/100
# 0s - loss: 1.6132e-04
# Epoch 71/100
# 0s - loss: 1.3307e-04
# Epoch 72/100
# 0s - loss: 1.3622e-04
# Epoch 73/100
# 0s - loss: 1.4232e-04
# Epoch 74/100
# 0s - loss: 1.3673e-04
# Epoch 75/100
# 0s - loss: 1.1695e-04
# Epoch 76/100
# 0s - loss: 1.3390e-04
# Epoch 77/100
# 0s - loss: 1.3460e-04
# Epoch 78/100
# 0s - loss: 1.2331e-04
# Epoch 79/100
# 0s - loss: 1.1891e-04
# Epoch 80/100
# 0s - loss: 1.2090e-04
# Epoch 81/100
# 0s - loss: 1.3643e-04
# Epoch 82/100
# 0s - loss: 1.2843e-04
# Epoch 83/100
# 0s - loss: 1.3438e-04
# Epoch 84/100
# 0s - loss: 1.0420e-04
# Epoch 85/100
# 0s - loss: 1.2596e-04
# Epoch 86/100
# 0s - loss: 1.2495e-04
# Epoch 87/100
# 0s - loss: 1.1576e-04
# Epoch 88/100
# 0s - loss: 1.3896e-04
# Epoch 89/100
# 0s - loss: 1.2743e-04
# Epoch 90/100
# 0s - loss: 1.2604e-04
# Epoch 91/100
# 0s - loss: 1.1495e-04
# Epoch 92/100
# 0s - loss: 1.1004e-04
# Epoch 93/100
# 0s - loss: 9.5705e-05
# Epoch 94/100
# 0s - loss: 1.2498e-04
# Epoch 95/100
# 0s - loss: 1.2032e-04
# Epoch 96/100
# 0s - loss: 1.0682e-04
# Epoch 97/100
# 0s - loss: 1.1794e-04
# Epoch 98/100
# 0s - loss: 1.1259e-04
# Epoch 99/100
# 0s - loss: 1.2358e-04
# Epoch 100/100
# 0s - loss: 1.2397e-04

# %%
nn_plot_in_sample(nn, train_nn, bbox_loc=(1.45,1))

# %%
nn_scaled_forecast = nn_predict_series(nn, 
                                      last_obs_creator_nn(train_nn, lags_for_nn), 
                                      len(test))
nn_forecast = scaler_back(nn_scaled_forecast, scaler(train)[1], scaler(train)[2])

# %%
nn_plot_out_sample(nn_forecast, test, bbox_loc=(1.43,1))

# %%
errors_out_sample(test, nn_forecast)
# Out:
# {'MAE': 0.090129282562272817,
#  'MSE': 0.009517944988136802,
#  'RMSE': 0.09755995586374977}

# %% [markdown]
# #### Second launch

# %%
def assemble_model(n_lags):
    model = Sequential()
    # Layers
    model.add(Dense(10, input_dim=n_lags, activation='sigmoid'))
    model.add(Dense(10, input_dim=10, activation='sigmoid'))
    #model.add(Dense(10, input_dim=10, activation='sigmoid'))
    model.add(Dense(1, input_dim=10))
    # Compilation
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

nn = assemble_model(lags_for_nn)
nn.fit(np.array(train_nn.iloc[:, :-1]), 
       np.array(train_nn.iloc[:, -1]), 
       nb_epoch=100, 
       verbose=2,
       batch_size=1)

nn_scaled_forecast = nn_predict_series(nn, 
                                      last_obs_creator_nn(train_nn, lags_for_nn), 
                                      len(test))
nn_forecast = scaler_back(nn_scaled_forecast, scaler(train)[1], scaler(train)[2])
# Out:
# Epoch 1/100
# 1s - loss: 0.4438
# Epoch 2/100
# 0s - loss: 0.0728
# Epoch 3/100
# 0s - loss: 0.0625
# Epoch 4/100
# 0s - loss: 0.0518
# Epoch 5/100
# 0s - loss: 0.0398
# Epoch 6/100
# 0s - loss: 0.0288
# Epoch 7/100
# 0s - loss: 0.0182
# Epoch 8/100
# 0s - loss: 0.0102
# Epoch 9/100
# 0s - loss: 0.0048
# Epoch 10/100
# 0s - loss: 0.0020
# Epoch 11/100
# 0s - loss: 8.5672e-04
# Epoch 12/100
# 0s - loss: 4.5558e-04
# Epoch 13/100
# 0s - loss: 3.4102e-04
# Epoch 14/100
# 0s - loss: 3.1263e-04
# Epoch 15/100
# 0s - loss: 2.9627e-04
# Epoch 16/100
# 0s - loss: 3.1224e-04
# Epoch 17/100
# 0s - loss: 3.0692e-04
# Epoch 18/100
# 0s - loss: 2.9815e-04
# Epoch 19/100
# 0s - loss: 2.9610e-04
# Epoch 20/100
# 0s - loss: 2.8730e-04
# Epoch 21/100
# 0s - loss: 2.8508e-04
# Epoch 22/100
# 0s - loss: 2.7410e-04
# Epoch 23/100
# 0s - loss: 3.0101e-04
# Epoch 24/100
# 0s - loss: 2.5915e-04
# Epoch 25/100
# 0s - loss: 2.6319e-04
# Epoch 26/100
# 0s - loss: 2.6963e-04
# Epoch 27/100
# 0s - loss: 2.5775e-04
# Epoch 28/100
# 0s - loss: 2.6052e-04
# Epoch 29/100
# 0s - loss: 2.4939e-04
# Epoch 30/100
# 0s - loss: 2.5674e-04
# Epoch 31/100
# 0s - loss: 2.5912e-04
# Epoch 32/100
# 0s - loss: 2.4113e-04
# Epoch 33/100
# 0s - loss: 2.8062e-04
# Epoch 34/100
# 0s - loss: 2.6739e-04
# Epoch 35/100
# 0s - loss: 2.6039e-04
# Epoch 36/100
# 0s - loss: 2.4042e-04
# Epoch 37/100
# 0s - loss: 2.7268e-04
# Epoch 38/100
# 0s - loss: 2.4566e-04
# Epoch 39/100
# 0s - loss: 3.0000e-04
# Epoch 40/100
# 0s - loss: 2.3873e-04
# Epoch 41/100
# 0s - loss: 2.2613e-04
# Epoch 42/100
# 0s - loss: 2.1664e-04
# Epoch 43/100
# 0s - loss: 2.6242e-04
# Epoch 44/100
# 0s - loss: 2.0116e-04
# Epoch 45/100
# 0s - loss: 2.1052e-04
# Epoch 46/100
# 0s - loss: 2.4964e-04
# Epoch 47/100
# 0s - loss: 1.9744e-04
# Epoch 48/100
# 0s - loss: 2.0587e-04
# Epoch 49/100
# 0s - loss: 1.9406e-04
# Epoch 50/100
# 0s - loss: 2.0479e-04
# Epoch 51/100
# 0s - loss: 2.1699e-04
# Epoch 52/100
# 0s - loss: 1.9727e-04
# Epoch 53/100
# 0s - loss: 1.9140e-04
# Epoch 54/100
# 0s - loss: 1.9552e-04
# Epoch 55/100
# 0s - loss: 1.9811e-04
# Epoch 56/100
# 0s - loss: 2.0055e-04
# Epoch 57/100
# 0s - loss: 1.8769e-04
# Epoch 58/100
# 0s - loss: 1.8196e-04
# Epoch 59/100
# 0s - loss: 1.9262e-04
# Epoch 60/100
# 0s - loss: 1.7700e-04
# Epoch 61/100
# 0s - loss: 1.8794e-04
# Epoch 62/100
# 0s - loss: 1.6158e-04
# Epoch 63/100
# 0s - loss: 2.1244e-04
# Epoch 64/100
# 0s - loss: 1.9537e-04
# Epoch 65/100
# 0s - loss: 1.7195e-04
# Epoch 66/100
# 0s - loss: 1.6478e-04
# Epoch 67/100
# 0s - loss: 1.7201e-04
# Epoch 68/100
# 0s - loss: 1.6699e-04
# Epoch 69/100
# 0s - loss: 1.9578e-04
# Epoch 70/100
# 0s - loss: 1.7566e-04
# Epoch 71/100
# 0s - loss: 1.6433e-04
# Epoch 72/100
# 0s - loss: 1.7274e-04
# Epoch 73/100
# 0s - loss: 1.4331e-04
# Epoch 74/100
# 0s - loss: 1.8167e-04
# Epoch 75/100
# 0s - loss: 1.5817e-04
# Epoch 76/100
# 0s - loss: 1.5372e-04
# Epoch 77/100
# 0s - loss: 1.3444e-04
# Epoch 78/100
# 0s - loss: 1.5893e-04
# Epoch 79/100
# 0s - loss: 1.5978e-04
# Epoch 80/100
# 0s - loss: 1.6201e-04
# Epoch 81/100
# 0s - loss: 2.0412e-04
# Epoch 82/100
# 0s - loss: 1.3885e-04
# Epoch 83/100
# 0s - loss: 1.4130e-04
# Epoch 84/100
# 0s - loss: 1.2761e-04
# Epoch 85/100
# 0s - loss: 1.6055e-04
# Epoch 86/100
# 0s - loss: 1.4102e-04
# Epoch 87/100
# 0s - loss: 1.5969e-04
# Epoch 88/100
# 0s - loss: 1.4566e-04
# Epoch 89/100
# 0s - loss: 1.5570e-04
# Epoch 90/100
# 0s - loss: 1.4982e-04
# Epoch 91/100
# 0s - loss: 1.4465e-04
# Epoch 92/100
# 0s - loss: 1.4946e-04
# Epoch 93/100
# 0s - loss: 1.2478e-04
# Epoch 94/100
# 0s - loss: 1.4548e-04
# Epoch 95/100
# 0s - loss: 1.2758e-04
# Epoch 96/100
# 0s - loss: 1.1976e-04
# Epoch 97/100
# 0s - loss: 1.1568e-04
# Epoch 98/100
# 0s - loss: 1.2031e-04
# Epoch 99/100
# 0s - loss: 1.3287e-04
# Epoch 100/100
# 0s - loss: 1.3081e-04

# %%
nn_plot_out_sample(nn_forecast, test, bbox_loc=(1.43,1))

# %%
errors_out_sample(test, nn_forecast)
# Out:
# {'MAE': 0.08557435521318224,
#  'MSE': 0.0085243928185042353,
#  'RMSE': 0.092327638432401354}

# %% [markdown]
# #### Third launch (anouther NN)

# %%
lags_for_nn = 2

train_nn = create_df_for_nn(scaled_train, lags_for_nn)

# %%
def assemble_model(n_lags):
    model = Sequential()
    # Layers
    model.add(Dense(10, input_dim=n_lags, activation='sigmoid'))
    model.add(Dense(10, input_dim=10, activation='sigmoid'))
    model.add(Dense(10, input_dim=10, activation='sigmoid'))
    model.add(Dropout(0.5))
    model.add(Dense(1, input_dim=10))
    # Compilation
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

nn = assemble_model(lags_for_nn)
nn.fit(np.array(train_nn.iloc[:, :-1]), 
       np.array(train_nn.iloc[:, -1]), 
       nb_epoch=100, 
       verbose=2,
       batch_size=1)

nn_scaled_forecast = nn_predict_series(nn, 
                                      last_obs_creator_nn(train_nn, lags_for_nn), 
                                      len(test))
nn_forecast = scaler_back(nn_scaled_forecast, scaler(train)[1], scaler(train)[2])
# Out:
# Epoch 1/100
# 0s - loss: 0.4692
# Epoch 2/100
# 0s - loss: 0.2987
# Epoch 3/100
# 0s - loss: 0.1913
# Epoch 4/100
# 0s - loss: 0.1649
# Epoch 5/100
# 0s - loss: 0.1437
# Epoch 6/100
# 0s - loss: 0.1142
# Epoch 7/100
# 0s - loss: 0.0990
# Epoch 8/100
# 0s - loss: 0.0917
# Epoch 9/100
# 0s - loss: 0.1107
# Epoch 10/100
# 0s - loss: 0.0878
# Epoch 11/100
# 0s - loss: 0.1102
# Epoch 12/100
# 0s - loss: 0.0857
# Epoch 13/100
# 0s - loss: 0.0901
# Epoch 14/100
# 0s - loss: 0.0848
# Epoch 15/100
# 0s - loss: 0.0760
# Epoch 16/100
# 0s - loss: 0.0839
# Epoch 17/100
# 0s - loss: 0.0748
# Epoch 18/100
# 0s - loss: 0.0698
# Epoch 19/100
# 0s - loss: 0.0657
# Epoch 20/100
# 0s - loss: 0.0598
# Epoch 21/100
# 0s - loss: 0.0526
# Epoch 22/100
# 0s - loss: 0.0458
# Epoch 23/100
# 0s - loss: 0.0374
# Epoch 24/100
# 0s - loss: 0.0361
# Epoch 25/100
# 0s - loss: 0.0350
# Epoch 26/100
# 0s - loss: 0.0425
# Epoch 27/100
# 0s - loss: 0.0403
# Epoch 28/100
# 0s - loss: 0.0239
# Epoch 29/100
# 0s - loss: 0.0337
# Epoch 30/100
# 0s - loss: 0.0334
# Epoch 31/100
# 0s - loss: 0.0305
# Epoch 32/100
# 0s - loss: 0.0255
# Epoch 33/100
# 0s - loss: 0.0226
# Epoch 34/100
# 0s - loss: 0.0197
# Epoch 35/100
# 0s - loss: 0.0211
# Epoch 36/100
# 0s - loss: 0.0245
# Epoch 37/100
# 0s - loss: 0.0249
# Epoch 38/100
# 0s - loss: 0.0227
# Epoch 39/100
# 0s - loss: 0.0212
# Epoch 40/100
# 0s - loss: 0.0251
# Epoch 41/100
# 0s - loss: 0.0243
# Epoch 42/100
# 0s - loss: 0.0184
# Epoch 43/100
# 0s - loss: 0.0246
# Epoch 44/100
# 0s - loss: 0.0192
# Epoch 45/100
# 0s - loss: 0.0212
# Epoch 46/100
# 0s - loss: 0.0177
# Epoch 47/100
# 0s - loss: 0.0200
# Epoch 48/100
# 0s - loss: 0.0177
# Epoch 49/100
# 0s - loss: 0.0199
# Epoch 50/100
# 0s - loss: 0.0161
# Epoch 51/100
# 0s - loss: 0.0231
# Epoch 52/100
# 0s - loss: 0.0139
# Epoch 53/100
# 0s - loss: 0.0190
# Epoch 54/100
# 0s - loss: 0.0179
# Epoch 55/100
# 0s - loss: 0.0149
# Epoch 56/100
# 0s - loss: 0.0161
# Epoch 57/100
# 0s - loss: 0.0172
# Epoch 58/100
# 0s - loss: 0.0171
# Epoch 59/100
# 0s - loss: 0.0201
# Epoch 60/100
# 0s - loss: 0.0176
# Epoch 61/100
# 0s - loss: 0.0120
# Epoch 62/100
# 0s - loss: 0.0145
# Epoch 63/100
# 0s - loss: 0.0176
# Epoch 64/100
# 0s - loss: 0.0163
# Epoch 65/100
# 0s - loss: 0.0139
# Epoch 66/100
# 0s - loss: 0.0126
# Epoch 67/100
# 0s - loss: 0.0160
# Epoch 68/100
# 0s - loss: 0.0144
# Epoch 69/100
# 0s - loss: 0.0172
# Epoch 70/100
# 0s - loss: 0.0182
# Epoch 71/100
# 0s - loss: 0.0199
# Epoch 72/100
# 0s - loss: 0.0137
# Epoch 73/100
# 0s - loss: 0.0203
# Epoch 74/100
# 0s - loss: 0.0164
# Epoch 75/100
# 0s - loss: 0.0146
# Epoch 76/100
# 0s - loss: 0.0210
# Epoch 77/100
# 0s - loss: 0.0149
# Epoch 78/100
# 0s - loss: 0.0174
# Epoch 79/100
# 0s - loss: 0.0186
# Epoch 80/100
# 0s - loss: 0.0158
# Epoch 81/100
# 0s - loss: 0.0176
# Epoch 82/100
# 0s - loss: 0.0145
# Epoch 83/100
# 0s - loss: 0.0140
# Epoch 84/100
# 0s - loss: 0.0146
# Epoch 85/100
# 0s - loss: 0.0172
# Epoch 86/100
# 0s - loss: 0.0162
# Epoch 87/100
# 0s - loss: 0.0213
# Epoch 88/100
# 0s - loss: 0.0148
# Epoch 89/100
# 0s - loss: 0.0146
# Epoch 90/100
# 0s - loss: 0.0147
# Epoch 91/100
# 0s - loss: 0.0133
# Epoch 92/100
# 0s - loss: 0.0161
# Epoch 93/100
# 0s - loss: 0.0186
# Epoch 94/100
# 0s - loss: 0.0163
# Epoch 95/100
# 0s - loss: 0.0200
# Epoch 96/100
# 0s - loss: 0.0182
# Epoch 97/100
# 0s - loss: 0.0180
# Epoch 98/100
# 0s - loss: 0.0190
# Epoch 99/100
# 0s - loss: 0.0190
# Epoch 100/100
# 0s - loss: 0.0189

# %%
nn_plot_in_sample(nn, train_nn, bbox_loc=(1.45,1))

# %%
nn_plot_out_sample(nn_forecast, test, bbox_loc=(1.43,1))

# %%
errors_out_sample(test, nn_forecast)
# Out:
# {'MAE': 0.13699295767976549,
#  'MSE': 0.019766706267978353,
#  'RMSE': 0.14059411889541593}

# %% [markdown]
# ### Hybrid

# %%
resids_arima = get_resids_arima(train, arima_model, d=1)
plt.plot(resids_arima)
plt.show()

# %%
scaled_resids_arima = scaler(resids_arima)[0]

# %%
lags_nn = 2

df_nn_resid = create_df_for_nn_residuals(scaled_resids_arima[1:], lags_nn)

def assemble_model(n_lags):
    model = Sequential()
    # Layers
    model.add(Dense(10, input_dim=n_lags, activation='sigmoid'))
    model.add(Dense(10, input_dim=10, activation='sigmoid'))
    model.add(Dropout(0.5))
    model.add(Dense(10, input_dim=10, activation='sigmoid'))
    model.add(Dense(1, input_dim=10))
    # Compilation
    model.compile(loss='mean_squared_error', optimizer='adam')
    return(model)

nn_resid = assemble_model(lags_nn)
nn_resid.fit(np.array(df_nn_resid.iloc[:, :-1]), 
       np.array(df_nn_resid.iloc[:, -1]), 
       nb_epoch=100, 
       verbose=2,
       batch_size=1)
# Out:
# Epoch 1/100
# 1s - loss: 0.0939
# Epoch 2/100
# 0s - loss: 0.0561
# Epoch 3/100
# 0s - loss: 0.0516
# Epoch 4/100
# 0s - loss: 0.0490
# Epoch 5/100
# 0s - loss: 0.0469
# Epoch 6/100
# 0s - loss: 0.0437
# Epoch 7/100
# 0s - loss: 0.0436
# Epoch 8/100
# 0s - loss: 0.0421
# Epoch 9/100
# 0s - loss: 0.0418
# Epoch 10/100
# 0s - loss: 0.0431
# Epoch 11/100
# 0s - loss: 0.0408
# Epoch 12/100
# 0s - loss: 0.0425
# Epoch 13/100
# 0s - loss: 0.0408
# Epoch 14/100
# 0s - loss: 0.0400
# Epoch 15/100
# 0s - loss: 0.0401
# Epoch 16/100
# 0s - loss: 0.0412
# Epoch 17/100
# 0s - loss: 0.0393
# Epoch 18/100
# 0s - loss: 0.0362
# Epoch 19/100
# 0s - loss: 0.0328
# Epoch 20/100
# 0s - loss: 0.0327
# Epoch 21/100
# 0s - loss: 0.0306
# Epoch 22/100
# 0s - loss: 0.0301
# Epoch 23/100
# 0s - loss: 0.0277
# Epoch 24/100
# 0s - loss: 0.0274
# Epoch 25/100
# 0s - loss: 0.0238
# Epoch 26/100
# 0s - loss: 0.0210
# Epoch 27/100
# 0s - loss: 0.0234
# Epoch 28/100
# 0s - loss: 0.0197
# Epoch 29/100
# 0s - loss: 0.0187
# Epoch 30/100
# 0s - loss: 0.0240
# Epoch 31/100
# 0s - loss: 0.0198
# Epoch 32/100
# 0s - loss: 0.0172
# Epoch 33/100
# 0s - loss: 0.0165
# Epoch 34/100
# 0s - loss: 0.0189
# Epoch 35/100
# 0s - loss: 0.0148
# Epoch 36/100
# 0s - loss: 0.0155
# Epoch 37/100
# 0s - loss: 0.0157
# Epoch 38/100
# 0s - loss: 0.0158
# Epoch 39/100
# 0s - loss: 0.0169
# Epoch 40/100
# 0s - loss: 0.0160
# Epoch 41/100
# 0s - loss: 0.0159
# Epoch 42/100
# 0s - loss: 0.0143
# Epoch 43/100
# 0s - loss: 0.0141
# Epoch 44/100
# 0s - loss: 0.0155
# Epoch 45/100
# 0s - loss: 0.0154
# Epoch 46/100
# 0s - loss: 0.0135
# Epoch 47/100
# 0s - loss: 0.0158
# Epoch 48/100
# 0s - loss: 0.0150
# Epoch 49/100
# 0s - loss: 0.0136
# Epoch 50/100
# 0s - loss: 0.0140
# Epoch 51/100
# 0s - loss: 0.0151
# Epoch 52/100
# 0s - loss: 0.0141
# Epoch 53/100
# 0s - loss: 0.0141
# Epoch 54/100
# 0s - loss: 0.0121
# Epoch 55/100
# 0s - loss: 0.0142
# Epoch 56/100
# 0s - loss: 0.0121
# Epoch 57/100
# 0s - loss: 0.0136
# Epoch 58/100
# 0s - loss: 0.0127
# Epoch 59/100
# 0s - loss: 0.0119
# Epoch 60/100
# 0s - loss: 0.0135
# Epoch 61/100
# 0s - loss: 0.0119
# Epoch 62/100
# 0s - loss: 0.0135
# Epoch 63/100
# 0s - loss: 0.0121
# Epoch 64/100
# 0s - loss: 0.0121
# Epoch 65/100
# 0s - loss: 0.0154
# Epoch 66/100
# 0s - loss: 0.0146
# Epoch 67/100
# 0s - loss: 0.0105
# Epoch 68/100
# 0s - loss: 0.0141
# Epoch 69/100
# 0s - loss: 0.0135
# Epoch 70/100
# 0s - loss: 0.0114
# Epoch 71/100
# 0s - loss: 0.0115
# Epoch 72/100
# 0s - loss: 0.0134
# Epoch 73/100
# 0s - loss: 0.0111
# Epoch 74/100
# 0s - loss: 0.0121
# Epoch 75/100
# 0s - loss: 0.0130
# Epoch 76/100
# 0s - loss: 0.0116
# Epoch 77/100
# 0s - loss: 0.0108
# Epoch 78/100
# 0s - loss: 0.0125
# Epoch 79/100
# 0s - loss: 0.0131
# Epoch 80/100
# 0s - loss: 0.0103
# Epoch 81/100
# 0s - loss: 0.0127
# Epoch 82/100
# 0s - loss: 0.0126
# Epoch 83/100
# 0s - loss: 0.0140
# Epoch 84/100
# 0s - loss: 0.0115
# Epoch 85/100
# 0s - loss: 0.0123
# Epoch 86/100
# 0s - loss: 0.0106
# Epoch 87/100
# 0s - loss: 0.0119
# Epoch 88/100
# 0s - loss: 0.0109
# Epoch 89/100
# 0s - loss: 0.0115
# Epoch 90/100
# 0s - loss: 0.0109
# Epoch 91/100
# 0s - loss: 0.0134
# Epoch 92/100
# 0s - loss: 0.0109
# Epoch 93/100
# 0s - loss: 0.0115
# Epoch 94/100
# 0s - loss: 0.0111
# Epoch 95/100
# 0s - loss: 0.0105
# Epoch 96/100
# 0s - loss: 0.0118
# Epoch 97/100
# 0s - loss: 0.0109
# Epoch 98/100
# 0s - loss: 0.0118
# Epoch 99/100
# 0s - loss: 0.0120
# Epoch 100/100
# 0s - loss: 0.0115

# %%
plt.plot(np.array(df_nn_resid.iloc[:, -1]), label='Resid')
plt.plot(nn_resid.predict(np.array(df_nn_resid.iloc[:, :-1])), label='Forecast')
plt.legend(bbox_to_anchor=(1.36,1), loc='best')
plt.show()

# %%
nn_scaled_resid_forecast = nn_predict_series(nn_resid, 
                                      last_lags_resid_df_for_nn(resids_arima, test, lags_nn), 
                                      len(test))

nn_resids_forecast = scaler_back(nn_scaled_resid_forecast, scaler(resids_arima)[1], scaler(resids_arima)[2])

hybrid_forecast = hybrid_predict_series(forc_arima, nn_resids_forecast)

# %%
hybrid_plot_forecast(forc_arima, nn_resids_forecast, test)

# %%
errors_out_sample(test, hybrid_forecast)
# Out:
# {'MAE': 0.030399512064256173,
#  'MSE': 0.0010462970509883267,
#  'RMSE': 0.032346515283540614}

# %% [markdown]
# ---

# %% [markdown]
# # Personal Income and Its Disposition

# %%
pers_inc = df.iloc[48, 1:186].copy()
pers_inc.index = pd.DatetimeIndex(start='1969-01', end='2015-04', freq='Q')

# %%
plt.plot([np.log(i) for i in pers_inc.tolist()])

# %%
pers_inc
# Out:
# 1969-03-31      771.3
# 1969-06-30      790.4
# 1969-09-30        812
# 1969-12-31      827.3
# 1970-03-31      841.8
# 1970-06-30      859.6
# 1970-09-30        874
# 1970-12-31      882.9
# 1971-03-31        903
# 1971-06-30      926.4
# 1971-09-30      940.5
# 1971-12-31      958.7
# 1972-03-31        986
# 1972-06-30     1003.5
# 1972-09-30     1029.2
# 1972-12-31     1075.7
# 1973-03-31     1093.3
# 1973-06-30     1122.6
# 1973-09-30       1150
# 1973-12-31     1188.2
# 1974-03-31     1204.4
# 1974-06-30     1230.4
# 1974-09-30     1266.6
# 1974-12-31       1296
# 1975-03-31     1315.9
# 1975-06-30     1347.5
# 1975-09-30     1384.1
# 1975-12-31       1420
# 1976-03-31     1452.6
# 1976-06-30       1477
#                ...
# 2007-12-31    12178.9
# 2008-03-31    12360.6
# 2008-06-30    12512.4
# 2008-09-30    12472.1
# 2008-12-31    12373.4
# 2009-03-31    12054.4
# 2009-06-30    12110.4
# 2009-09-30    12059.5
# 2009-12-31    12125.5
# 2010-03-31    12187.1
# 2010-06-30    12365.6
# 2010-09-30    12496.1
# 2010-12-31    12668.6
# 2011-03-31    13025.1
# 2011-06-30    13142.2
# 2011-09-30    13294.8
# 2011-12-31    13345.8
# 2012-03-31    13650.7
# 2012-06-30    13776.1
# 2012-09-30    13828.9
# 2012-12-31    14295.1
# 2013-03-31    13977.2
# 2013-06-30    14131.3
# 2013-09-30    14247.4
# 2013-12-31    14311.7
# 2014-03-31    14484.7
# 2014-06-30    14660.5
# 2014-09-30    14811.2
# 2014-12-31    14979.3
# 2015-03-31    15129.2
# Freq: Q-DEC, Name: 48, dtype: object

# %%
test_stationarity(pers_inc)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   4.061463
# p-value                          1.000000
# #Lags Used                      12.000000
# Number of Observations Used    172.000000
# Critical Value (10%)            -2.575809
# Critical Value (5%)             -2.878495
# Critical Value (1%)             -3.468952
# dtype: float64

# %%
test_stationarity(diff_series(pers_inc))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.563036
# p-value                          0.100880
# #Lags Used                      14.000000
# Number of Observations Used    169.000000
# Critical Value (10%)            -2.575971
# Critical Value (5%)             -2.878799
# Critical Value (1%)             -3.469648
# dtype: float64

# %%
test_stationarity(diff_series(diff_series(pers_inc)))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -6.837962e+00
# p-value                        1.821920e-09
# #Lags Used                     1.400000e+01
# Number of Observations Used    1.680000e+02
# Critical Value (10%)          -2.576027e+00
# Critical Value (5%)           -2.878903e+00
# Critical Value (1%)           -3.469886e+00
# dtype: float64

# %%
train = pers_inc[:-9]
test = pers_inc[-9:]

# %% [markdown]
# ### ARIMA

# %%
correlogram(diff_series(diff_series(train)))

# %%
arima_model = ARIMA(np.array(train), order=(1,2,2)).fit(trend='nc')
print(arima_model.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                   D2.y   No. Observations:                  174
# Model:                 ARIMA(1, 2, 2)   Log Likelihood                -968.664
# Method:                       css-mle   S.D. of innovations             63.096
# Date:                Sat, 28 Jan 2017   AIC                           1945.329
# Time:                        23:49:26   BIC                           1957.965
# Sample:                             2   HQIC                          1950.455
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# ar.L1.D2.y    -0.9184      0.051    -17.942      0.000        -1.019    -0.818
# ma.L1.D2.y     0.3600      0.088      4.083      0.000         0.187     0.533
# ma.L2.D2.y    -0.6184      0.077     -8.069      0.000        -0.769    -0.468
#                                     Roots
# =============================================================================
#                  Real           Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.0889           +0.0000j            1.0889            0.5000
# MA.1           -1.0134           +0.0000j            1.0134            0.5000
# MA.2            1.5956           +0.0000j            1.5956            0.0000
# -----------------------------------------------------------------------------

# %%
arima_model.plot_predict()
plt.show()

# %%
forc_arima = arima_model.forecast(len(test))
plot_forecast_out_only(test, forc_arima, bbox_loc=(1.03,1))

# %%
errors_out_sample(test, forc_arima[0])
# Out:
# {'MAE': 1065.7303376178138, 'MSE': 1221927.5661761612}

# %% [markdown]
# ### ANN

# %%
scaled_train = scaler(train)[0]

lags_for_nn = 2

train_nn = create_df_for_nn(scaled_train, lags_for_nn)

def assemble_model(n_lags):
    model = Sequential()
    # Layers
    model.add(Dense(10, input_dim=n_lags, activation='sigmoid'))
    model.add(Dense(10, input_dim=10, activation='sigmoid'))
    model.add(Dropout(0.5))
    model.add(Dense(10, input_dim=10, activation='sigmoid'))
    model.add(Dense(1, input_dim=10))
    # Compilation
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

nn = assemble_model(lags_for_nn)
nn.fit(np.array(train_nn.iloc[:, :-1]), 
       np.array(train_nn.iloc[:, -1]), 
       nb_epoch=100, 
       verbose=2,
       batch_size=1)
# Out:
# Epoch 1/100
# 1s - loss: 0.1131
# Epoch 2/100
# 0s - loss: 0.0895
# Epoch 3/100
# 0s - loss: 0.0923
# Epoch 4/100
# 0s - loss: 0.0887
# Epoch 5/100
# 0s - loss: 0.0903
# Epoch 6/100
# 0s - loss: 0.0876
# Epoch 7/100
# 0s - loss: 0.0843
# Epoch 8/100
# 0s - loss: 0.0847
# Epoch 9/100
# 0s - loss: 0.0792
# Epoch 10/100
# 0s - loss: 0.0801
# Epoch 11/100
# 0s - loss: 0.0691
# Epoch 12/100
# 0s - loss: 0.0712
# Epoch 13/100
# 0s - loss: 0.0626
# Epoch 14/100
# 0s - loss: 0.0568
# Epoch 15/100
# 0s - loss: 0.0439
# Epoch 16/100
# 0s - loss: 0.0294
# Epoch 17/100
# 0s - loss: 0.0341
# Epoch 18/100
# 0s - loss: 0.0301
# Epoch 19/100
# 0s - loss: 0.0275
# Epoch 20/100
# 0s - loss: 0.0308
# Epoch 21/100
# 0s - loss: 0.0287
# Epoch 22/100
# 0s - loss: 0.0218
# Epoch 23/100
# 0s - loss: 0.0228
# Epoch 24/100
# 0s - loss: 0.0276
# Epoch 25/100
# 0s - loss: 0.0198
# Epoch 26/100
# 0s - loss: 0.0203
# Epoch 27/100
# 0s - loss: 0.0217
# Epoch 28/100
# 0s - loss: 0.0174
# Epoch 29/100
# 0s - loss: 0.0156
# Epoch 30/100
# 0s - loss: 0.0181
# Epoch 31/100
# 0s - loss: 0.0167
# Epoch 32/100
# 0s - loss: 0.0212
# Epoch 33/100
# 0s - loss: 0.0170
# Epoch 34/100
# 0s - loss: 0.0178
# Epoch 35/100
# 0s - loss: 0.0166
# Epoch 36/100
# 0s - loss: 0.0188
# Epoch 37/100
# 0s - loss: 0.0144
# Epoch 38/100
# 0s - loss: 0.0181
# Epoch 39/100
# 0s - loss: 0.0157
# Epoch 40/100
# 0s - loss: 0.0150
# Epoch 41/100
# 0s - loss: 0.0190
# Epoch 42/100
# 0s - loss: 0.0161
# Epoch 43/100
# 0s - loss: 0.0128
# Epoch 44/100
# 0s - loss: 0.0154
# Epoch 45/100
# 0s - loss: 0.0147
# Epoch 46/100
# 0s - loss: 0.0177
# Epoch 47/100
# 0s - loss: 0.0164
# Epoch 48/100
# 0s - loss: 0.0144
# Epoch 49/100
# 0s - loss: 0.0144
# Epoch 50/100
# 0s - loss: 0.0117
# Epoch 51/100
# 0s - loss: 0.0142
# Epoch 52/100
# 0s - loss: 0.0117
# Epoch 53/100
# 0s - loss: 0.0138
# Epoch 54/100
# 0s - loss: 0.0153
# Epoch 55/100
# 0s - loss: 0.0120
# Epoch 56/100
# 0s - loss: 0.0140
# Epoch 57/100
# 0s - loss: 0.0104
# Epoch 58/100
# 0s - loss: 0.0144
# Epoch 59/100
# 0s - loss: 0.0133
# Epoch 60/100
# 0s - loss: 0.0155
# Epoch 61/100
# 0s - loss: 0.0125
# Epoch 62/100
# 0s - loss: 0.0153
# Epoch 63/100
# 0s - loss: 0.0139
# Epoch 64/100
# 0s - loss: 0.0104
# Epoch 65/100
# 0s - loss: 0.0150
# Epoch 66/100
# 0s - loss: 0.0118
# Epoch 67/100
# 0s - loss: 0.0146
# Epoch 68/100
# 0s - loss: 0.0116
# Epoch 69/100
# 0s - loss: 0.0164
# Epoch 70/100
# 0s - loss: 0.0095
# Epoch 71/100
# 0s - loss: 0.0101
# Epoch 72/100
# 0s - loss: 0.0128
# Epoch 73/100
# 0s - loss: 0.0109
# Epoch 74/100
# 0s - loss: 0.0113
# Epoch 75/100
# 0s - loss: 0.0114
# Epoch 76/100
# 0s - loss: 0.0118
# Epoch 77/100
# 0s - loss: 0.0098
# Epoch 78/100
# 0s - loss: 0.0088
# Epoch 79/100
# 0s - loss: 0.0091
# Epoch 80/100
# 0s - loss: 0.0112
# Epoch 81/100
# 0s - loss: 0.0108
# Epoch 82/100
# 0s - loss: 0.0106
# Epoch 83/100
# 0s - loss: 0.0084
# Epoch 84/100
# 0s - loss: 0.0080
# Epoch 85/100
# 0s - loss: 0.0074
# Epoch 86/100
# 0s - loss: 0.0115
# Epoch 87/100
# 0s - loss: 0.0073
# Epoch 88/100
# 0s - loss: 0.0115
# Epoch 89/100
# 0s - loss: 0.0105
# Epoch 90/100
# 0s - loss: 0.0104
# Epoch 91/100
# 0s - loss: 0.0095
# Epoch 92/100
# 0s - loss: 0.0073
# Epoch 93/100
# 0s - loss: 0.0102
# Epoch 94/100
# 0s - loss: 0.0098
# Epoch 95/100
# 0s - loss: 0.0088
# Epoch 96/100
# 0s - loss: 0.0057
# Epoch 97/100
# 0s - loss: 0.0068
# Epoch 98/100
# 0s - loss: 0.0091
# Epoch 99/100
# 0s - loss: 0.0113
# Epoch 100/100
# 0s - loss: 0.0060

# %%
nn_plot_in_sample(nn, train_nn, bbox_loc=(1.45,1))

# %%
nn_scaled_forecast = nn_predict_series(nn, 
                                      last_obs_creator_nn(train_nn, lags_for_nn), 
                                      len(test))
nn_forecast = scaler_back(nn_scaled_forecast, scaler(train)[1], scaler(train)[2])

nn_plot_out_sample(nn_forecast, test, bbox_loc=(1.43,1))

# %%
errors_out_sample(test, forc_arima[0])
# Out:
# {'MAE': 6987.1847489337433, 'MSE': 48838365.931372486}

# %% [markdown]
# ### Hybrid

# %%
resids_arima = get_resids_arima(train, arima_model, d=2)
plt.plot(resids_arima)
plt.show()

# %%
scaled_resids_arima = scaler(resids_arima)[0]

lags_nn = 4

df_nn_resid = create_df_for_nn_residuals(scaled_resids_arima[1:], lags_nn)

def assemble_model(n_lags):
    model = Sequential()
    # Layers
    model.add(Dense(10, input_dim=n_lags, activation='sigmoid'))
    model.add(Dense(10, input_dim=10, activation='sigmoid'))
    model.add(Dropout(0.5))
    model.add(Dense(10, input_dim=10, activation='sigmoid'))
    model.add(Dense(1, input_dim=10))
    # Compilation
    model.compile(loss='mean_squared_error', optimizer='adam')
    return(model)

nn_resid = assemble_model(lags_nn)
nn_resid.fit(np.array(df_nn_resid.iloc[:, :-1]), 
       np.array(df_nn_resid.iloc[:, -1]), 
       nb_epoch=100, 
       verbose=2,
       batch_size=1)
# Out:
# Epoch 1/100
# 1s - loss: 0.4687
# Epoch 2/100
# 0s - loss: 0.0402
# Epoch 3/100
# 0s - loss: 0.0321
# Epoch 4/100
# 0s - loss: 0.0254
# Epoch 5/100
# 0s - loss: 0.0243
# Epoch 6/100
# 0s - loss: 0.0187
# Epoch 7/100
# 0s - loss: 0.0217
# Epoch 8/100
# 0s - loss: 0.0205
# Epoch 9/100
# 0s - loss: 0.0204
# Epoch 10/100
# 0s - loss: 0.0190
# Epoch 11/100
# 0s - loss: 0.0184
# Epoch 12/100
# 0s - loss: 0.0177
# Epoch 13/100
# 0s - loss: 0.0176
# Epoch 14/100
# 0s - loss: 0.0176
# Epoch 15/100
# 0s - loss: 0.0171
# Epoch 16/100
# 0s - loss: 0.0182
# Epoch 17/100
# 0s - loss: 0.0179
# Epoch 18/100
# 0s - loss: 0.0171
# Epoch 19/100
# 0s - loss: 0.0164
# Epoch 20/100
# 0s - loss: 0.0174
# Epoch 21/100
# 0s - loss: 0.0177
# Epoch 22/100
# 0s - loss: 0.0174
# Epoch 23/100
# 0s - loss: 0.0183
# Epoch 24/100
# 0s - loss: 0.0177
# Epoch 25/100
# 0s - loss: 0.0171
# Epoch 26/100
# 0s - loss: 0.0169
# Epoch 27/100
# 0s - loss: 0.0167
# Epoch 28/100
# 0s - loss: 0.0170
# Epoch 29/100
# 0s - loss: 0.0166
# Epoch 30/100
# 0s - loss: 0.0159
# Epoch 31/100
# 0s - loss: 0.0160
# Epoch 32/100
# 0s - loss: 0.0156
# Epoch 33/100
# 0s - loss: 0.0152
# Epoch 34/100
# 0s - loss: 0.0153
# Epoch 35/100
# 0s - loss: 0.0151
# Epoch 36/100
# 0s - loss: 0.0146
# Epoch 37/100
# 0s - loss: 0.0144
# Epoch 38/100
# 0s - loss: 0.0146
# Epoch 39/100
# 0s - loss: 0.0132
# Epoch 40/100
# 0s - loss: 0.0142
# Epoch 41/100
# 0s - loss: 0.0137
# Epoch 42/100
# 0s - loss: 0.0115
# Epoch 43/100
# 0s - loss: 0.0126
# Epoch 44/100
# 0s - loss: 0.0099
# Epoch 45/100
# 0s - loss: 0.0120
# Epoch 46/100
# 0s - loss: 0.0114
# Epoch 47/100
# 0s - loss: 0.0093
# Epoch 48/100
# 0s - loss: 0.0097
# Epoch 49/100
# 0s - loss: 0.0103
# Epoch 50/100
# 0s - loss: 0.0104
# Epoch 51/100
# 0s - loss: 0.0092
# Epoch 52/100
# 0s - loss: 0.0095
# Epoch 53/100
# 0s - loss: 0.0102
# Epoch 54/100
# 0s - loss: 0.0092
# Epoch 55/100
# 0s - loss: 0.0090
# Epoch 56/100
# 0s - loss: 0.0087
# Epoch 57/100
# 0s - loss: 0.0104
# Epoch 58/100
# 0s - loss: 0.0093
# Epoch 59/100
# 0s - loss: 0.0106
# Epoch 60/100
# 0s - loss: 0.0092
# Epoch 61/100
# 0s - loss: 0.0095
# Epoch 62/100
# 0s - loss: 0.0085
# Epoch 63/100
# 0s - loss: 0.0093
# Epoch 64/100
# 0s - loss: 0.0091
# Epoch 65/100
# 0s - loss: 0.0093
# Epoch 66/100
# 0s - loss: 0.0095
# Epoch 67/100
# 0s - loss: 0.0088
# Epoch 68/100
# 0s - loss: 0.0088
# Epoch 69/100
# 0s - loss: 0.0097
# Epoch 70/100
# 0s - loss: 0.0084
# Epoch 71/100
# 0s - loss: 0.0094
# Epoch 72/100
# 0s - loss: 0.0099
# Epoch 73/100
# 0s - loss: 0.0086
# Epoch 74/100
# 0s - loss: 0.0092
# Epoch 75/100
# 0s - loss: 0.0089
# Epoch 76/100
# 0s - loss: 0.0080
# Epoch 77/100
# 0s - loss: 0.0085
# Epoch 78/100
# 0s - loss: 0.0093
# Epoch 79/100
# 0s - loss: 0.0090
# Epoch 80/100
# 0s - loss: 0.0074
# Epoch 81/100
# 0s - loss: 0.0086
# Epoch 82/100
# 0s - loss: 0.0091
# Epoch 83/100
# 0s - loss: 0.0090
# Epoch 84/100
# 0s - loss: 0.0081
# Epoch 85/100
# 0s - loss: 0.0087
# Epoch 86/100
# 0s - loss: 0.0070
# Epoch 87/100
# 0s - loss: 0.0074
# Epoch 88/100
# 0s - loss: 0.0083
# Epoch 89/100
# 0s - loss: 0.0079
# Epoch 90/100
# 0s - loss: 0.0097
# Epoch 91/100
# 0s - loss: 0.0090
# Epoch 92/100
# 0s - loss: 0.0087
# Epoch 93/100
# 0s - loss: 0.0082
# Epoch 94/100
# 0s - loss: 0.0083
# Epoch 95/100
# 0s - loss: 0.0078
# Epoch 96/100
# 0s - loss: 0.0075
# Epoch 97/100
# 0s - loss: 0.0090
# Epoch 98/100
# 0s - loss: 0.0092
# Epoch 99/100
# 0s - loss: 0.0087
# Epoch 100/100
# 0s - loss: 0.0086

# %%
plt.plot(np.array(df_nn_resid.iloc[:, -1]), label='Resid')
plt.plot(nn_resid.predict(np.array(df_nn_resid.iloc[:, :-1])), label='Forecast')
plt.legend(bbox_to_anchor=(1.36,1), loc='best')
plt.show()

# %%
nn_scaled_resid_forecast = nn_predict_series(nn_resid, 
                                      last_lags_resid_df_for_nn(resids_arima, test, lags_nn), 
                                      len(test))

nn_resids_forecast = scaler_back(nn_scaled_resid_forecast, scaler(resids_arima)[1], scaler(resids_arima)[2])

hybrid_forecast = hybrid_predict_series(forc_arima, nn_resids_forecast)

# %%
hybrid_plot_forecast(forc_arima, nn_resids_forecast, test)

# %%
errors_out_sample(test, hybrid_forecast)
# Out:
# {'MAE': 897.90668005216708, 'MSE': 903027.80959665019}

# %%
nn_resids_forecast
# Out:
# array([-197.32269287, -197.32269287, -192.06793213, -144.26533508,
#        -163.31016541, -158.02134705, -155.26098633, -152.0018158 ,
#        -150.83995056], dtype=float32)

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # Wages and salaries

# %%
wages = df.iloc[49, 1:186].copy()
wages.index = pd.DatetimeIndex(start='1969-01', end='2015-04', freq='Q')

# %%
plt.plot([np.log(i) for i in wages.tolist()])

# %%
test_stationarity(wages)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   2.094862
# p-value                          0.998784
# #Lags Used                      14.000000
# Number of Observations Used    170.000000
# Critical Value (10%)            -2.575917
# Critical Value (5%)             -2.878696
# Critical Value (1%)             -3.469413
# dtype: float64

# %%
test_stationarity(diff_series(wages))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.624336
# p-value                          0.088071
# #Lags Used                      13.000000
# Number of Observations Used    170.000000
# Critical Value (10%)            -2.575917
# Critical Value (5%)             -2.878696
# Critical Value (1%)             -3.469413
# dtype: float64

# %%
test_stationarity(diff_series(diff_series(wages)))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -5.853942e+00
# p-value                        3.536029e-07
# #Lags Used                     1.200000e+01
# Number of Observations Used    1.700000e+02
# Critical Value (10%)          -2.575917e+00
# Critical Value (5%)           -2.878696e+00
# Critical Value (1%)           -3.469413e+00
# dtype: float64

# %%
train = wages[:-9]
test = wages[-9:]

# %% [markdown]
# ### ARIMA

# %%
correlogram(diff_series(diff_series(train)))

# %%
arima_model = ARIMA(np.array(train), order=(2,2,1)).fit(trend='nc')
print(arima_model.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                   D2.y   No. Observations:                  174
# Model:                 ARIMA(2, 2, 1)   Log Likelihood                -900.330
# Method:                       css-mle   S.D. of innovations             42.657
# Date:                Sun, 29 Jan 2017   AIC                           1808.660
# Time:                        00:44:21   BIC                           1821.297
# Sample:                             2   HQIC                          1813.786
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# ar.L1.D2.y    -0.2611      0.223     -1.173      0.242        -0.697     0.175
# ar.L2.D2.y    -0.0753      0.167     -0.451      0.653        -0.403     0.252
# ma.L1.D2.y    -0.5587      0.216     -2.586      0.011        -0.982    -0.135
#                                     Roots
# =============================================================================
#                  Real           Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.7344           -3.2057j            3.6448           -0.3289
# AR.2           -1.7344           +3.2057j            3.6448            0.3289
# MA.1            1.7899           +0.0000j            1.7899            0.0000
# -----------------------------------------------------------------------------

# %%
arima_model.plot_predict()
plt.show()

# %%
forc_arima = arima_model.forecast(len(test))
plot_forecast_out_only(test, forc_arima, bbox_loc=(1.03,1))

# %%
errors_out_sample(test, forc_arima[0])
# Out:
# {'MAE': 206.02636217736847, 'MSE': 44059.652539840681}

# %% [markdown]
# ### ANN

# %%
scaled_train = scaler(train)[0]

lags_for_nn = 2

train_nn = create_df_for_nn(scaled_train, lags_for_nn)

def assemble_model(n_lags):
    model = Sequential()
    # Layers
    model.add(Dense(10, input_dim=n_lags, activation='sigmoid'))
    model.add(Dropout(0.5))
    model.add(Dense(10, input_dim=10, activation='sigmoid'))
    model.add(Dense(1, input_dim=10))
    # Compilation
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

nn = assemble_model(lags_for_nn)
nn.fit(np.array(train_nn.iloc[:, :-1]), 
       np.array(train_nn.iloc[:, -1]), 
       nb_epoch=100, 
       verbose=2,
       batch_size=1)
# Out:
# Epoch 1/100
# 1s - loss: 0.1106
# Epoch 2/100
# 0s - loss: 0.0975
# Epoch 3/100
# 0s - loss: 0.0850
# Epoch 4/100
# 0s - loss: 0.0802
# Epoch 5/100
# 0s - loss: 0.0955
# Epoch 6/100
# 0s - loss: 0.0831
# Epoch 7/100
# 0s - loss: 0.0772
# Epoch 8/100
# 0s - loss: 0.0797
# Epoch 9/100
# 0s - loss: 0.0671
# Epoch 10/100
# 0s - loss: 0.0649
# Epoch 11/100
# 0s - loss: 0.0603
# Epoch 12/100
# 0s - loss: 0.0507
# Epoch 13/100
# 0s - loss: 0.0468
# Epoch 14/100
# 0s - loss: 0.0448
# Epoch 15/100
# 0s - loss: 0.0542
# Epoch 16/100
# 0s - loss: 0.0454
# Epoch 17/100
# 0s - loss: 0.0343
# Epoch 18/100
# 0s - loss: 0.0391
# Epoch 19/100
# 0s - loss: 0.0378
# Epoch 20/100
# 0s - loss: 0.0376
# Epoch 21/100
# 0s - loss: 0.0362
# Epoch 22/100
# 0s - loss: 0.0300
# Epoch 23/100
# 0s - loss: 0.0337
# Epoch 24/100
# 0s - loss: 0.0299
# Epoch 25/100
# 0s - loss: 0.0357
# Epoch 26/100
# 0s - loss: 0.0289
# Epoch 27/100
# 0s - loss: 0.0249
# Epoch 28/100
# 0s - loss: 0.0286
# Epoch 29/100
# 0s - loss: 0.0313
# Epoch 30/100
# 0s - loss: 0.0301
# Epoch 31/100
# 0s - loss: 0.0232
# Epoch 32/100
# 0s - loss: 0.0197
# Epoch 33/100
# 0s - loss: 0.0284
# Epoch 34/100
# 0s - loss: 0.0251
# Epoch 35/100
# 0s - loss: 0.0247
# Epoch 36/100
# 0s - loss: 0.0213
# Epoch 37/100
# 0s - loss: 0.0230
# Epoch 38/100
# 0s - loss: 0.0159
# Epoch 39/100
# 0s - loss: 0.0267
# Epoch 40/100
# 0s - loss: 0.0223
# Epoch 41/100
# 0s - loss: 0.0192
# Epoch 42/100
# 0s - loss: 0.0192
# Epoch 43/100
# 0s - loss: 0.0243
# Epoch 44/100
# 0s - loss: 0.0195
# Epoch 45/100
# 0s - loss: 0.0230
# Epoch 46/100
# 0s - loss: 0.0238
# Epoch 47/100
# 0s - loss: 0.0226
# Epoch 48/100
# 0s - loss: 0.0172
# Epoch 49/100
# 0s - loss: 0.0184
# Epoch 50/100
# 0s - loss: 0.0139
# Epoch 51/100
# 0s - loss: 0.0164
# Epoch 52/100
# 0s - loss: 0.0143
# Epoch 53/100
# 0s - loss: 0.0137
# Epoch 54/100
# 0s - loss: 0.0157
# Epoch 55/100
# 0s - loss: 0.0132
# Epoch 56/100
# 0s - loss: 0.0164
# Epoch 57/100
# 0s - loss: 0.0229
# Epoch 58/100
# 0s - loss: 0.0126
# Epoch 59/100
# 0s - loss: 0.0155
# Epoch 60/100
# 0s - loss: 0.0149
# Epoch 61/100
# 0s - loss: 0.0149
# Epoch 62/100
# 0s - loss: 0.0172
# Epoch 63/100
# 0s - loss: 0.0161
# Epoch 64/100
# 0s - loss: 0.0153
# Epoch 65/100
# 0s - loss: 0.0120
# Epoch 66/100
# 0s - loss: 0.0171
# Epoch 67/100
# 0s - loss: 0.0168
# Epoch 68/100
# 0s - loss: 0.0110
# Epoch 69/100
# 0s - loss: 0.0133
# Epoch 70/100
# 0s - loss: 0.0159
# Epoch 71/100
# 0s - loss: 0.0149
# Epoch 72/100
# 0s - loss: 0.0107
# Epoch 73/100
# 0s - loss: 0.0146
# Epoch 74/100
# 0s - loss: 0.0133
# Epoch 75/100
# 0s - loss: 0.0162
# Epoch 76/100
# 0s - loss: 0.0107
# Epoch 77/100
# 0s - loss: 0.0148
# Epoch 78/100
# 0s - loss: 0.0115
# Epoch 79/100
# 0s - loss: 0.0130
# Epoch 80/100
# 0s - loss: 0.0113
# Epoch 81/100
# 0s - loss: 0.0114
# Epoch 82/100
# 0s - loss: 0.0079
# Epoch 83/100
# 0s - loss: 0.0085
# Epoch 84/100
# 0s - loss: 0.0130
# Epoch 85/100
# 0s - loss: 0.0125
# Epoch 86/100
# 0s - loss: 0.0121
# Epoch 87/100
# 0s - loss: 0.0141
# Epoch 88/100
# 0s - loss: 0.0103
# Epoch 89/100
# 0s - loss: 0.0150
# Epoch 90/100
# 0s - loss: 0.0119
# Epoch 91/100
# 0s - loss: 0.0084
# Epoch 92/100
# 0s - loss: 0.0106
# Epoch 93/100
# 0s - loss: 0.0117
# Epoch 94/100
# 0s - loss: 0.0122
# Epoch 95/100
# 0s - loss: 0.0144
# Epoch 96/100
# 0s - loss: 0.0136
# Epoch 97/100
# 0s - loss: 0.0130
# Epoch 98/100
# 0s - loss: 0.0107
# Epoch 99/100
# 0s - loss: 0.0118
# Epoch 100/100
# 0s - loss: 0.0081

# %%
nn_plot_in_sample(nn, train_nn, bbox_loc=(1.45,1))

# %%
nn_scaled_forecast = nn_predict_series(nn, 
                                      last_obs_creator_nn(train_nn, lags_for_nn), 
                                      len(test))
nn_forecast = scaler_back(nn_scaled_forecast, scaler(train)[1], scaler(train)[2])

nn_plot_out_sample(nn_forecast, test, bbox_loc=(1.43,1))

# %%
errors_out_sample(test, hybrid_forecast)
# Out:
# {'MAE': 8091.1177911632776, 'MSE': 65685813.906355776}

# %% [markdown]
# ### Hybrid

# %%
resids_arima = get_resids_arima(train, arima_model, d=2)
plt.plot(resids_arima)
plt.show()

# %%
scaled_resids_arima = scaler(resids_arima)[0]

lags_nn = 2

df_nn_resid = create_df_for_nn_residuals(scaled_resids_arima[1:], lags_nn)

def assemble_model(n_lags):
    model = Sequential()
    # Layers
    model.add(Dense(10, input_dim=n_lags, activation='sigmoid'))
    model.add(Dropout(0.5))
    model.add(Dense(10, input_dim=10, activation='sigmoid'))
    model.add(Dense(1, input_dim=10))
    # Compilation
    model.compile(loss='mean_squared_error', optimizer='adam')
    return(model)

nn_resid = assemble_model(lags_nn)
nn_resid.fit(np.array(df_nn_resid.iloc[:, :-1]), 
       np.array(df_nn_resid.iloc[:, -1]), 
       nb_epoch=100, 
       verbose=2,
       batch_size=1)
# Out:
# Epoch 1/100
# 2s - loss: 0.1873
# Epoch 2/100
# 0s - loss: 0.0545
# Epoch 3/100
# 0s - loss: 0.0427
# Epoch 4/100
# 0s - loss: 0.0351
# Epoch 5/100
# 0s - loss: 0.0299
# Epoch 6/100
# 0s - loss: 0.0273
# Epoch 7/100
# 0s - loss: 0.0255
# Epoch 8/100
# 0s - loss: 0.0249
# Epoch 9/100
# 0s - loss: 0.0253
# Epoch 10/100
# 0s - loss: 0.0247
# Epoch 11/100
# 0s - loss: 0.0248
# Epoch 12/100
# 0s - loss: 0.0235
# Epoch 13/100
# 0s - loss: 0.0224
# Epoch 14/100
# 0s - loss: 0.0245
# Epoch 15/100
# 0s - loss: 0.0229
# Epoch 16/100
# 0s - loss: 0.0222
# Epoch 17/100
# 0s - loss: 0.0236
# Epoch 18/100
# 0s - loss: 0.0208
# Epoch 19/100
# 0s - loss: 0.0224
# Epoch 20/100
# 0s - loss: 0.0229
# Epoch 21/100
# 0s - loss: 0.0216
# Epoch 22/100
# 0s - loss: 0.0226
# Epoch 23/100
# 0s - loss: 0.0211
# Epoch 24/100
# 0s - loss: 0.0223
# Epoch 25/100
# 0s - loss: 0.0198
# Epoch 26/100
# 0s - loss: 0.0209
# Epoch 27/100
# 0s - loss: 0.0208
# Epoch 28/100
# 0s - loss: 0.0221
# Epoch 29/100
# 0s - loss: 0.0211
# Epoch 30/100
# 0s - loss: 0.0203
# Epoch 31/100
# 0s - loss: 0.0198
# Epoch 32/100
# 0s - loss: 0.0196
# Epoch 33/100
# 0s - loss: 0.0180
# Epoch 34/100
# 0s - loss: 0.0171
# Epoch 35/100
# 0s - loss: 0.0185
# Epoch 36/100
# 0s - loss: 0.0170
# Epoch 37/100
# 0s - loss: 0.0189
# Epoch 38/100
# 0s - loss: 0.0172
# Epoch 39/100
# 0s - loss: 0.0164
# Epoch 40/100
# 0s - loss: 0.0164
# Epoch 41/100
# 0s - loss: 0.0165
# Epoch 42/100
# 0s - loss: 0.0160
# Epoch 43/100
# 0s - loss: 0.0147
# Epoch 44/100
# 0s - loss: 0.0172
# Epoch 45/100
# 0s - loss: 0.0174
# Epoch 46/100
# 0s - loss: 0.0145
# Epoch 47/100
# 0s - loss: 0.0152
# Epoch 48/100
# 0s - loss: 0.0155
# Epoch 49/100
# 0s - loss: 0.0156
# Epoch 50/100
# 0s - loss: 0.0147
# Epoch 51/100
# 0s - loss: 0.0152
# Epoch 52/100
# 0s - loss: 0.0159
# Epoch 53/100
# 0s - loss: 0.0147
# Epoch 54/100
# 0s - loss: 0.0145
# Epoch 55/100
# 0s - loss: 0.0144
# Epoch 56/100
# 0s - loss: 0.0156
# Epoch 57/100
# 0s - loss: 0.0152
# Epoch 58/100
# 0s - loss: 0.0132
# Epoch 59/100
# 0s - loss: 0.0161
# Epoch 60/100
# 0s - loss: 0.0141
# Epoch 61/100
# 0s - loss: 0.0152
# Epoch 62/100
# 0s - loss: 0.0129
# Epoch 63/100
# 0s - loss: 0.0151
# Epoch 64/100
# 0s - loss: 0.0129
# Epoch 65/100
# 0s - loss: 0.0139
# Epoch 66/100
# 0s - loss: 0.0112
# Epoch 67/100
# 0s - loss: 0.0140
# Epoch 68/100
# 0s - loss: 0.0104
# Epoch 69/100
# 0s - loss: 0.0113
# Epoch 70/100
# 0s - loss: 0.0136
# Epoch 71/100
# 0s - loss: 0.0116
# Epoch 72/100
# 0s - loss: 0.0126
# Epoch 73/100
# 0s - loss: 0.0117
# Epoch 74/100
# 0s - loss: 0.0134
# Epoch 75/100
# 0s - loss: 0.0132
# Epoch 76/100
# 0s - loss: 0.0132
# Epoch 77/100
# 0s - loss: 0.0117
# Epoch 78/100
# 0s - loss: 0.0114
# Epoch 79/100
# 0s - loss: 0.0146
# Epoch 80/100
# 0s - loss: 0.0105
# Epoch 81/100
# 0s - loss: 0.0114
# Epoch 82/100
# 0s - loss: 0.0114
# Epoch 83/100
# 0s - loss: 0.0115
# Epoch 84/100
# 0s - loss: 0.0131
# Epoch 85/100
# 0s - loss: 0.0112
# Epoch 86/100
# 0s - loss: 0.0120
# Epoch 87/100
# 0s - loss: 0.0103
# Epoch 88/100
# 0s - loss: 0.0119
# Epoch 89/100
# 0s - loss: 0.0113
# Epoch 90/100
# 0s - loss: 0.0097
# Epoch 91/100
# 0s - loss: 0.0109
# Epoch 92/100
# 0s - loss: 0.0109
# Epoch 93/100
# 0s - loss: 0.0127
# Epoch 94/100
# 0s - loss: 0.0120
# Epoch 95/100
# 0s - loss: 0.0122
# Epoch 96/100
# 0s - loss: 0.0107
# Epoch 97/100
# 0s - loss: 0.0119
# Epoch 98/100
# 0s - loss: 0.0100
# Epoch 99/100
# 0s - loss: 0.0122
# Epoch 100/100
# 0s - loss: 0.0101

# %%
plt.plot(np.array(df_nn_resid.iloc[:, -1]), label='Resid')
plt.plot(nn_resid.predict(np.array(df_nn_resid.iloc[:, :-1])), label='Forecast')
plt.legend(bbox_to_anchor=(1.36,1), loc='best')
plt.show()

# %%
nn_scaled_resid_forecast = nn_predict_series(nn_resid, 
                                      last_lags_resid_df_for_nn(resids_arima, test, lags_nn), 
                                      len(test))

nn_resids_forecast = scaler_back(nn_scaled_resid_forecast, scaler(resids_arima)[1], scaler(resids_arima)[2])

hybrid_forecast = hybrid_predict_series(forc_arima, nn_resids_forecast)

# %%
hybrid_plot_forecast(forc_arima, nn_resids_forecast, test)

# %%
errors_out_sample(test, hybrid_forecast)
# Out:
# {'MAE': 141.15109896325714, 'MSE': 22628.521059064551}

# %%
nn_resids_forecast
# Out:
# array([-86.10334778, -86.10334778, -71.09324646, -66.83618164,
#        -61.0412178 , -57.51320267, -54.17682266, -51.61431122, -49.39569092], dtype=float32)

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # Personal consumption expenditures (PCE)

# %%
pers_consump_exp = df.iloc[55, 1:186].copy()
pers_consump_exp.index = pd.DatetimeIndex(start='1969-01', end='2015-04', freq='Q')

# %%
plt.plot([np.log(i) for i in pers_consump_exp.tolist()])

# %%
test_stationarity(pers_consump_exp)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   0.975815
# p-value                          0.994004
# #Lags Used                       3.000000
# Number of Observations Used    181.000000
# Critical Value (10%)            -2.575355
# Critical Value (5%)             -2.877644
# Critical Value (1%)             -3.467005
# dtype: float64

# %%
test_stationarity(diff_series(pers_consump_exp))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -3.731468
# p-value                          0.003692
# #Lags Used                       2.000000
# Number of Observations Used    181.000000
# Critical Value (10%)            -2.575355
# Critical Value (5%)             -2.877644
# Critical Value (1%)             -3.467005
# dtype: float64

# %%
train = pers_consump_exp[:-9]
test = pers_consump_exp[-9:]

# %% [markdown]
# ### ARIMA

# %%
correlogram(diff_series(train))

# %%
arima_model = ARIMA(np.array(train), order=(4,1,1)).fit(trend='nc')
print(arima_model.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                  175
# Model:                 ARIMA(4, 1, 1)   Log Likelihood                 -57.074
# Method:                       css-mle   S.D. of innovations              0.334
# Date:                Sun, 29 Jan 2017   AIC                            126.147
# Time:                        02:07:11   BIC                            145.136
# Sample:                             1   HQIC                           133.849
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# ar.L1.D.y     -0.3401      0.572     -0.594      0.553        -1.462     0.781
# ar.L2.D.y      0.5146      0.194      2.650      0.009         0.134     0.895
# ar.L3.D.y      0.4902      0.153      3.211      0.002         0.191     0.789
# ar.L4.D.y      0.1571      0.209      0.751      0.453        -0.253     0.567
# ma.L1.D.y      0.6980      0.560      1.247      0.214        -0.399     1.795
#                                     Roots
# =============================================================================
#                  Real           Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0601           -0.0000j            1.0601           -0.0000
# AR.2           -1.7323           -0.0000j            1.7323           -0.5000
# AR.3           -1.2238           -1.4030j            1.8617           -0.3642
# AR.4           -1.2238           +1.4030j            1.8617            0.3642
# MA.1           -1.4327           +0.0000j            1.4327            0.5000
# -----------------------------------------------------------------------------

# %%
arima_model.plot_predict()
plt.show()

# %%
forc_arima = arima_model.forecast(len(test))
plot_forecast_out_only(test, forc_arima, bbox_loc=(1.03,1))

# %%
errors_out_sample(test, forc_arima[0])
# Out:
# {'MAE': 1.7282073885857758, 'MSE': 4.0591636832557993}

# %% [markdown]
# ### ANN

# %%
scaled_train = scaler(train)[0]

lags_for_nn = 2

train_nn = create_df_for_nn(scaled_train, lags_for_nn)

def assemble_model(n_lags):
    model = Sequential()
    # Layers
    model.add(Dense(10, input_dim=n_lags, activation='sigmoid'))
    model.add(Dense(10, input_dim=10, activation='sigmoid'))
    model.add(Dropout(0.5))
    model.add(Dense(10, input_dim=10, activation='sigmoid'))
    model.add(Dense(1, input_dim=10))
    # Compilation
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

nn = assemble_model(lags_for_nn)
nn.fit(np.array(train_nn.iloc[:, :-1]), 
       np.array(train_nn.iloc[:, -1]), 
       nb_epoch=100, 
       verbose=2,
       batch_size=1)
# Out:
# Epoch 1/100
# 1s - loss: 0.2994
# Epoch 2/100
# 0s - loss: 0.1154
# Epoch 3/100
# 0s - loss: 0.1104
# Epoch 4/100
# 0s - loss: 0.1068
# Epoch 5/100
# 0s - loss: 0.1021
# Epoch 6/100
# 0s - loss: 0.1016
# Epoch 7/100
# 0s - loss: 0.0982
# Epoch 8/100
# 0s - loss: 0.1036
# Epoch 9/100
# 0s - loss: 0.0945
# Epoch 10/100
# 0s - loss: 0.0865
# Epoch 11/100
# 0s - loss: 0.0815
# Epoch 12/100
# 0s - loss: 0.0796
# Epoch 13/100
# 0s - loss: 0.0753
# Epoch 14/100
# 0s - loss: 0.0579
# Epoch 15/100
# 0s - loss: 0.0603
# Epoch 16/100
# 0s - loss: 0.0488
# Epoch 17/100
# 0s - loss: 0.0418
# Epoch 18/100
# 0s - loss: 0.0438
# Epoch 19/100
# 0s - loss: 0.0366
# Epoch 20/100
# 0s - loss: 0.0300
# Epoch 21/100
# 0s - loss: 0.0420
# Epoch 22/100
# 0s - loss: 0.0305
# Epoch 23/100
# 0s - loss: 0.0294
# Epoch 24/100
# 0s - loss: 0.0280
# Epoch 25/100
# 0s - loss: 0.0327
# Epoch 26/100
# 0s - loss: 0.0263
# Epoch 27/100
# 0s - loss: 0.0244
# Epoch 28/100
# 0s - loss: 0.0236
# Epoch 29/100
# 0s - loss: 0.0261
# Epoch 30/100
# 0s - loss: 0.0215
# Epoch 31/100
# 0s - loss: 0.0235
# Epoch 32/100
# 0s - loss: 0.0203
# Epoch 33/100
# 0s - loss: 0.0204
# Epoch 34/100
# 0s - loss: 0.0186
# Epoch 35/100
# 0s - loss: 0.0164
# Epoch 36/100
# 0s - loss: 0.0205
# Epoch 37/100
# 0s - loss: 0.0181
# Epoch 38/100
# 0s - loss: 0.0201
# Epoch 39/100
# 0s - loss: 0.0161
# Epoch 40/100
# 0s - loss: 0.0177
# Epoch 41/100
# 0s - loss: 0.0163
# Epoch 42/100
# 0s - loss: 0.0243
# Epoch 43/100
# 0s - loss: 0.0165
# Epoch 44/100
# 0s - loss: 0.0174
# Epoch 45/100
# 0s - loss: 0.0191
# Epoch 46/100
# 0s - loss: 0.0221
# Epoch 47/100
# 0s - loss: 0.0161
# Epoch 48/100
# 0s - loss: 0.0183
# Epoch 49/100
# 0s - loss: 0.0122
# Epoch 50/100
# 0s - loss: 0.0170
# Epoch 51/100
# 0s - loss: 0.0119
# Epoch 52/100
# 0s - loss: 0.0152
# Epoch 53/100
# 0s - loss: 0.0155
# Epoch 54/100
# 0s - loss: 0.0129
# Epoch 55/100
# 0s - loss: 0.0157
# Epoch 56/100
# 0s - loss: 0.0116
# Epoch 57/100
# 0s - loss: 0.0150
# Epoch 58/100
# 0s - loss: 0.0138
# Epoch 59/100
# 0s - loss: 0.0147
# Epoch 60/100
# 0s - loss: 0.0138
# Epoch 61/100
# 0s - loss: 0.0102
# Epoch 62/100
# 0s - loss: 0.0112
# Epoch 63/100
# 0s - loss: 0.0158
# Epoch 64/100
# 0s - loss: 0.0117
# Epoch 65/100
# 0s - loss: 0.0102
# Epoch 66/100
# 0s - loss: 0.0118
# Epoch 67/100
# 0s - loss: 0.0121
# Epoch 68/100
# 0s - loss: 0.0109
# Epoch 69/100
# 0s - loss: 0.0087
# Epoch 70/100
# 0s - loss: 0.0125
# Epoch 71/100
# 0s - loss: 0.0120
# Epoch 72/100
# 0s - loss: 0.0121
# Epoch 73/100
# 0s - loss: 0.0090
# Epoch 74/100
# 0s - loss: 0.0118
# Epoch 75/100
# 0s - loss: 0.0086
# Epoch 76/100
# 0s - loss: 0.0086
# Epoch 77/100
# 0s - loss: 0.0098
# Epoch 78/100
# 0s - loss: 0.0129
# Epoch 79/100
# 0s - loss: 0.0087
# Epoch 80/100
# 0s - loss: 0.0096
# Epoch 81/100
# 0s - loss: 0.0113
# Epoch 82/100
# 0s - loss: 0.0100
# Epoch 83/100
# 0s - loss: 0.0112
# Epoch 84/100
# 0s - loss: 0.0080
# Epoch 85/100
# 0s - loss: 0.0112
# Epoch 86/100
# 0s - loss: 0.0081
# Epoch 87/100
# 0s - loss: 0.0081
# Epoch 88/100
# 0s - loss: 0.0081
# Epoch 89/100
# 0s - loss: 0.0087
# Epoch 90/100
# 0s - loss: 0.0108
# Epoch 91/100
# 0s - loss: 0.0097
# Epoch 92/100
# 0s - loss: 0.0111
# Epoch 93/100
# 0s - loss: 0.0073
# Epoch 94/100
# 0s - loss: 0.0084
# Epoch 95/100
# 0s - loss: 0.0114
# Epoch 96/100
# 0s - loss: 0.0112
# Epoch 97/100
# 0s - loss: 0.0097
# Epoch 98/100
# 0s - loss: 0.0081
# Epoch 99/100
# 0s - loss: 0.0068
# Epoch 100/100
# 0s - loss: 0.0116

# %%
nn_plot_in_sample(nn, train_nn, bbox_loc=(1.45,1))

# %%
nn_scaled_forecast = nn_predict_series(nn, 
                                      last_obs_creator_nn(train_nn, lags_for_nn), 
                                      len(test))
nn_forecast = scaler_back(nn_scaled_forecast, scaler(train)[1], scaler(train)[2])

nn_plot_out_sample(nn_forecast, test, bbox_loc=(1.43,1))

# %%
errors_out_sample(test, nn_forecast)
# Out:
# {'MAE': 10.626571607801649, 'MSE': 121.55495952439641}

# %% [markdown]
# ### Hybrid

# %%
resids_arima = get_resids_arima(train, arima_model, d=1)
plt.plot(resids_arima)
plt.show()

# %%
scaled_resids_arima = scaler(resids_arima)[0]

lags_nn = 2

df_nn_resid = create_df_for_nn_residuals(scaled_resids_arima[1:], lags_nn)

def assemble_model(n_lags):
    model = Sequential()
    # Layers
    model.add(Dense(10, input_dim=n_lags, activation='sigmoid'))
    model.add(Dropout(0.5))
    model.add(Dense(10, input_dim=10, activation='sigmoid'))
    model.add(Dropout(0.5))
    model.add(Dense(1, input_dim=10))
    # Compilation
    model.compile(loss='mean_squared_error', optimizer='adam')
    return(model)

nn_resid = assemble_model(lags_nn)
nn_resid.fit(np.array(df_nn_resid.iloc[:, :-1]), 
       np.array(df_nn_resid.iloc[:, -1]), 
       nb_epoch=100, 
       verbose=2,
       batch_size=1)
# Out:
# Epoch 1/100
# 2s - loss: 0.3425
# Epoch 2/100
# 0s - loss: 0.1582
# Epoch 3/100
# 0s - loss: 0.1265
# Epoch 4/100
# 0s - loss: 0.1189
# Epoch 5/100
# 0s - loss: 0.1203
# Epoch 6/100
# 0s - loss: 0.0707
# Epoch 7/100
# 0s - loss: 0.0615
# Epoch 8/100
# 0s - loss: 0.0432
# Epoch 9/100
# 0s - loss: 0.0460
# Epoch 10/100
# 0s - loss: 0.0437
# Epoch 11/100
# 0s - loss: 0.0401
# Epoch 12/100
# 0s - loss: 0.0408
# Epoch 13/100
# 0s - loss: 0.0391
# Epoch 14/100
# 0s - loss: 0.0360
# Epoch 15/100
# 0s - loss: 0.0348
# Epoch 16/100
# 0s - loss: 0.0348
# Epoch 17/100
# 0s - loss: 0.0328
# Epoch 18/100
# 0s - loss: 0.0343
# Epoch 19/100
# 0s - loss: 0.0351
# Epoch 20/100
# 0s - loss: 0.0294
# Epoch 21/100
# 0s - loss: 0.0322
# Epoch 22/100
# 0s - loss: 0.0295
# Epoch 23/100
# 0s - loss: 0.0313
# Epoch 24/100
# 0s - loss: 0.0305
# Epoch 25/100
# 0s - loss: 0.0301
# Epoch 26/100
# 0s - loss: 0.0312
# Epoch 27/100
# 0s - loss: 0.0302
# Epoch 28/100
# 0s - loss: 0.0305
# Epoch 29/100
# 0s - loss: 0.0294
# Epoch 30/100
# 0s - loss: 0.0299
# Epoch 31/100
# 0s - loss: 0.0303
# Epoch 32/100
# 0s - loss: 0.0296
# Epoch 33/100
# 0s - loss: 0.0301
# Epoch 34/100
# 0s - loss: 0.0295
# Epoch 35/100
# 0s - loss: 0.0299
# Epoch 36/100
# 0s - loss: 0.0293
# Epoch 37/100
# 0s - loss: 0.0302
# Epoch 38/100
# 0s - loss: 0.0283
# Epoch 39/100
# 0s - loss: 0.0299
# Epoch 40/100
# 0s - loss: 0.0298
# Epoch 41/100
# 0s - loss: 0.0295
# Epoch 42/100
# 0s - loss: 0.0295
# Epoch 43/100
# 0s - loss: 0.0294
# Epoch 44/100
# 0s - loss: 0.0282
# Epoch 45/100
# 0s - loss: 0.0289
# Epoch 46/100
# 0s - loss: 0.0294
# Epoch 47/100
# 0s - loss: 0.0279
# Epoch 48/100
# 0s - loss: 0.0298
# Epoch 49/100
# 0s - loss: 0.0297
# Epoch 50/100
# 0s - loss: 0.0283
# Epoch 51/100
# 0s - loss: 0.0291
# Epoch 52/100
# 0s - loss: 0.0297
# Epoch 53/100
# 0s - loss: 0.0282
# Epoch 54/100
# 0s - loss: 0.0285
# Epoch 55/100
# 0s - loss: 0.0289
# Epoch 56/100
# 0s - loss: 0.0276
# Epoch 57/100
# 0s - loss: 0.0265
# Epoch 58/100
# 0s - loss: 0.0278
# Epoch 59/100
# 0s - loss: 0.0292
# Epoch 60/100
# 0s - loss: 0.0264
# Epoch 61/100
# 0s - loss: 0.0282
# Epoch 62/100
# 0s - loss: 0.0271
# Epoch 63/100
# 0s - loss: 0.0255
# Epoch 64/100
# 0s - loss: 0.0268
# Epoch 65/100
# 0s - loss: 0.0266
# Epoch 66/100
# 0s - loss: 0.0263
# Epoch 67/100
# 0s - loss: 0.0269
# Epoch 68/100
# 0s - loss: 0.0246
# Epoch 69/100
# 0s - loss: 0.0215
# Epoch 70/100
# 0s - loss: 0.0262
# Epoch 71/100
# 0s - loss: 0.0226
# Epoch 72/100
# 0s - loss: 0.0228
# Epoch 73/100
# 0s - loss: 0.0233
# Epoch 74/100
# 0s - loss: 0.0237
# Epoch 75/100
# 0s - loss: 0.0223
# Epoch 76/100
# 0s - loss: 0.0239
# Epoch 77/100
# 0s - loss: 0.0219
# Epoch 78/100
# 0s - loss: 0.0236
# Epoch 79/100
# 0s - loss: 0.0220
# Epoch 80/100
# 0s - loss: 0.0208
# Epoch 81/100
# 0s - loss: 0.0237
# Epoch 82/100
# 0s - loss: 0.0217
# Epoch 83/100
# 0s - loss: 0.0185
# Epoch 84/100
# 0s - loss: 0.0220
# Epoch 85/100
# 0s - loss: 0.0224
# Epoch 86/100
# 0s - loss: 0.0217
# Epoch 87/100
# 0s - loss: 0.0221
# Epoch 88/100
# 0s - loss: 0.0256
# Epoch 89/100
# 0s - loss: 0.0210
# Epoch 90/100
# 0s - loss: 0.0195
# Epoch 91/100
# 0s - loss: 0.0177
# Epoch 92/100
# 0s - loss: 0.0175
# Epoch 93/100
# 0s - loss: 0.0182
# Epoch 94/100
# 0s - loss: 0.0194
# Epoch 95/100
# 0s - loss: 0.0183
# Epoch 96/100
# 0s - loss: 0.0223
# Epoch 97/100
# 0s - loss: 0.0220
# Epoch 98/100
# 0s - loss: 0.0188
# Epoch 99/100
# 0s - loss: 0.0160
# Epoch 100/100
# 0s - loss: 0.0215

# %%
plt.plot(np.array(df_nn_resid.iloc[:, -1]), label='Resid')
plt.plot(nn_resid.predict(np.array(df_nn_resid.iloc[:, :-1])), label='Forecast')
plt.legend(bbox_to_anchor=(1.36,1), loc='best')
plt.show()

# %%
nn_scaled_resid_forecast = nn_predict_series(nn_resid, 
                                      last_lags_resid_df_for_nn(resids_arima, test, lags_nn), 
                                      len(test))

nn_resids_forecast = scaler_back(nn_scaled_resid_forecast, scaler(resids_arima)[1], scaler(resids_arima)[2])

hybrid_forecast = hybrid_predict_series(forc_arima, nn_resids_forecast)

# %%
hybrid_plot_forecast(forc_arima, nn_resids_forecast, test)

# %%
errors_out_sample(test, hybrid_forecast)
# Out:
# {'MAE': 2.2756761965479817, 'MSE': 6.2002452576539424}

# %%
nn_resids_forecast
# Out:
# array([-0.61348492, -0.60577816, -0.54837602, -0.53890741, -0.52868181,
#        -0.52535295, -0.52305663, -0.52207565, -0.52150571], dtype=float32)

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # Real Personal Consumption Expenditures by Major Type of Product, Quantity Indexes
#
# # Goods

# %%
pers_goods = df.iloc[56, 1:186].copy()
pers_goods.index = pd.DatetimeIndex(start='1969-01', end='2015-04', freq='Q')

# %%
plt.plot([np.log(i) for i in gov_consump_inv.tolist()])

# %%
test_stationarity(pers_goods)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   1.222984
# p-value                          0.996141
# #Lags Used                       3.000000
# Number of Observations Used    181.000000
# Critical Value (10%)            -2.575355
# Critical Value (5%)             -2.877644
# Critical Value (1%)             -3.467005
# dtype: float64

# %%
test_stationarity(diff_series(pers_goods))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -4.720413
# p-value                          0.000077
# #Lags Used                       2.000000
# Number of Observations Used    181.000000
# Critical Value (10%)            -2.575355
# Critical Value (5%)             -2.877644
# Critical Value (1%)             -3.467005
# dtype: float64

# %%
train = pers_consump_exp[:-9]
test = pers_consump_exp[-9:]

# %% [markdown]
# ### ARIMA

# %%
correlogram(diff_series(train))

# %%
arima_model = ARIMA(np.array(train), order=(3,1,0)).fit(trend='c')
print(arima_model.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                  175
# Model:                 ARIMA(3, 1, 0)   Log Likelihood                 -52.420
# Method:                       css-mle   S.D. of innovations              0.326
# Date:                Sun, 29 Jan 2017   AIC                            114.839
# Time:                        02:17:00   BIC                            130.663
# Sample:                             1   HQIC                           121.258
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          0.4414      0.082      5.382      0.000         0.281     0.602
# ar.L1.D.y      0.2768      0.073      3.778      0.000         0.133     0.420
# ar.L2.D.y      0.2041      0.075      2.737      0.007         0.058     0.350
# ar.L3.D.y      0.2263      0.073      3.097      0.002         0.083     0.370
#                                     Roots
# =============================================================================
#                  Real           Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.1901           -0.0000j            1.1901           -0.0000
# AR.2           -1.0459           -1.6181j            1.9267           -0.3413
# AR.3           -1.0459           +1.6181j            1.9267            0.3413
# -----------------------------------------------------------------------------

# %%
arima_model.plot_predict()
plt.show()

# %%
forc_arima = arima_model.forecast(len(test))
plot_forecast_out_only(test, forc_arima, bbox_loc=(1.03,1))

# %%
errors_out_sample(test, forc_arima[0])
# Out:
# {'MAE': 1.2690263195914657, 'MSE': 2.136314488701311}

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ### ANN

# %%
scaled_train = scaler(train)[0]

lags_for_nn = 3

train_nn = create_df_for_nn(scaled_train, lags_for_nn)

def assemble_model(n_lags):
    model = Sequential()
    # Layers
    model.add(Dense(10, input_dim=n_lags, activation='sigmoid'))
    model.add(Dense(10, input_dim=10, activation='sigmoid'))
    model.add(Dropout(0.5))
    model.add(Dense(10, input_dim=10, activation='sigmoid'))
    model.add(Dense(1, input_dim=10))
    # Compilation
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

nn = assemble_model(lags_for_nn)
nn.fit(np.array(train_nn.iloc[:, :-1]), 
       np.array(train_nn.iloc[:, -1]), 
       nb_epoch=100, 
       verbose=2,
       batch_size=1)
# Out:
# Epoch 1/100
# 2s - loss: 0.1902
# Epoch 2/100
# 0s - loss: 0.1112
# Epoch 3/100
# 0s - loss: 0.1063
# Epoch 4/100
# 0s - loss: 0.0993
# Epoch 5/100
# 0s - loss: 0.0977
# Epoch 6/100
# 0s - loss: 0.0917
# Epoch 7/100
# 0s - loss: 0.0846
# Epoch 8/100
# 0s - loss: 0.0749
# Epoch 9/100
# 0s - loss: 0.0717
# Epoch 10/100
# 0s - loss: 0.0561
# Epoch 11/100
# 0s - loss: 0.0418
# Epoch 12/100
# 0s - loss: 0.0388
# Epoch 13/100
# 0s - loss: 0.0344
# Epoch 14/100
# 0s - loss: 0.0363
# Epoch 15/100
# 0s - loss: 0.0284
# Epoch 16/100
# 0s - loss: 0.0230
# Epoch 17/100
# 0s - loss: 0.0232
# Epoch 18/100
# 0s - loss: 0.0167
# Epoch 19/100
# 0s - loss: 0.0234
# Epoch 20/100
# 0s - loss: 0.0227
# Epoch 21/100
# 0s - loss: 0.0199
# Epoch 22/100
# 0s - loss: 0.0223
# Epoch 23/100
# 0s - loss: 0.0277
# Epoch 24/100
# 0s - loss: 0.0191
# Epoch 25/100
# 0s - loss: 0.0160
# Epoch 26/100
# 0s - loss: 0.0170
# Epoch 27/100
# 0s - loss: 0.0227
# Epoch 28/100
# 0s - loss: 0.0199
# Epoch 29/100
# 0s - loss: 0.0180
# Epoch 30/100
# 0s - loss: 0.0197
# Epoch 31/100
# 0s - loss: 0.0199
# Epoch 32/100
# 0s - loss: 0.0155
# Epoch 33/100
# 0s - loss: 0.0157
# Epoch 34/100
# 0s - loss: 0.0164
# Epoch 35/100
# 0s - loss: 0.0128
# Epoch 36/100
# 0s - loss: 0.0134
# Epoch 37/100
# 0s - loss: 0.0164
# Epoch 38/100
# 0s - loss: 0.0122
# Epoch 39/100
# 0s - loss: 0.0155
# Epoch 40/100
# 0s - loss: 0.0140
# Epoch 41/100
# 0s - loss: 0.0124
# Epoch 42/100
# 0s - loss: 0.0135
# Epoch 43/100
# 0s - loss: 0.0135
# Epoch 44/100
# 0s - loss: 0.0131
# Epoch 45/100
# 0s - loss: 0.0118
# Epoch 46/100
# 0s - loss: 0.0152
# Epoch 47/100
# 0s - loss: 0.0134
# Epoch 48/100
# 0s - loss: 0.0128
# Epoch 49/100
# 0s - loss: 0.0115
# Epoch 50/100
# 0s - loss: 0.0102
# Epoch 51/100
# 0s - loss: 0.0103
# Epoch 52/100
# 0s - loss: 0.0140
# Epoch 53/100
# 0s - loss: 0.0148
# Epoch 54/100
# 0s - loss: 0.0089
# Epoch 55/100
# 0s - loss: 0.0123
# Epoch 56/100
# 0s - loss: 0.0130
# Epoch 57/100
# 0s - loss: 0.0130
# Epoch 58/100
# 0s - loss: 0.0109
# Epoch 59/100
# 0s - loss: 0.0097
# Epoch 60/100
# 0s - loss: 0.0111
# Epoch 61/100
# 0s - loss: 0.0097
# Epoch 62/100
# 0s - loss: 0.0119
# Epoch 63/100
# 0s - loss: 0.0061
# Epoch 64/100
# 0s - loss: 0.0144
# Epoch 65/100
# 0s - loss: 0.0085
# Epoch 66/100
# 0s - loss: 0.0123
# Epoch 67/100
# 0s - loss: 0.0103
# Epoch 68/100
# 0s - loss: 0.0136
# Epoch 69/100
# 0s - loss: 0.0116
# Epoch 70/100
# 0s - loss: 0.0134
# Epoch 71/100
# 0s - loss: 0.0130
# Epoch 72/100
# 0s - loss: 0.0096
# Epoch 73/100
# 0s - loss: 0.0097
# Epoch 74/100
# 0s - loss: 0.0099
# Epoch 75/100
# 0s - loss: 0.0086
# Epoch 76/100
# 0s - loss: 0.0078
# Epoch 77/100
# 0s - loss: 0.0093
# Epoch 78/100
# 0s - loss: 0.0097
# Epoch 79/100
# 0s - loss: 0.0114
# Epoch 80/100
# 0s - loss: 0.0101
# Epoch 81/100
# 0s - loss: 0.0088
# Epoch 82/100
# 0s - loss: 0.0127
# Epoch 83/100
# 0s - loss: 0.0115
# Epoch 84/100
# 0s - loss: 0.0127
# Epoch 85/100
# 0s - loss: 0.0115
# Epoch 86/100
# 0s - loss: 0.0082
# Epoch 87/100
# 0s - loss: 0.0102
# Epoch 88/100
# 0s - loss: 0.0089
# Epoch 89/100
# 0s - loss: 0.0073
# Epoch 90/100
# 0s - loss: 0.0099
# Epoch 91/100
# 0s - loss: 0.0117
# Epoch 92/100
# 0s - loss: 0.0084
# Epoch 93/100
# 0s - loss: 0.0071
# Epoch 94/100
# 0s - loss: 0.0075
# Epoch 95/100
# 0s - loss: 0.0110
# Epoch 96/100
# 0s - loss: 0.0087
# Epoch 97/100
# 0s - loss: 0.0139
# Epoch 98/100
# 0s - loss: 0.0090
# Epoch 99/100
# 0s - loss: 0.0088
# Epoch 100/100
# 0s - loss: 0.0070

# %%
nn_plot_in_sample(nn, train_nn, bbox_loc=(1.45,1))

# %%
nn_scaled_forecast = nn_predict_series(nn, 
                                      last_obs_creator_nn(train_nn, lags_for_nn), 
                                      len(test))
nn_forecast = scaler_back(nn_scaled_forecast, scaler(train)[1], scaler(train)[2])

nn_plot_out_sample(nn_forecast, test, bbox_loc=(1.43,1))

# %%
errors_out_sample(test, nn_forecast)
# Out:
# {'MAE': 12.060408650716147, 'MSE': 149.17030466181689}

# %% [markdown]
# ### Hybrid

# %%
resids_arima = get_resids_arima(train, arima_model)
plt.plot(resids_arima)
plt.show()

# %%
scaled_resids_arima = scaler(resids_arima)[0]

lags_nn = 2

df_nn_resid = create_df_for_nn_residuals(scaled_resids_arima[1:], lags_nn)

def assemble_model(n_lags):
    model = Sequential()
    # Layers
    model.add(Dense(10, input_dim=n_lags, activation='sigmoid'))
    model.add(Dropout(0.5))
    model.add(Dense(10, input_dim=10, activation='sigmoid'))
    model.add(Dense(1, input_dim=10))
    # Compilation
    model.compile(loss='mean_squared_error', optimizer='adam')
    return(model)

nn_resid = assemble_model(lags_nn)
nn_resid.fit(np.array(df_nn_resid.iloc[:, :-1]), 
       np.array(df_nn_resid.iloc[:, -1]), 
       nb_epoch=100, 
       verbose=2,
       batch_size=1)
# Out:
# Epoch 1/100
# 2s - loss: 0.0567
# Epoch 2/100
# 0s - loss: 0.0390
# Epoch 3/100
# 0s - loss: 0.0380
# Epoch 4/100
# 0s - loss: 0.0328
# Epoch 5/100
# 0s - loss: 0.0305
# Epoch 6/100
# 0s - loss: 0.0277
# Epoch 7/100
# 0s - loss: 0.0292
# Epoch 8/100
# 0s - loss: 0.0296
# Epoch 9/100
# 0s - loss: 0.0262
# Epoch 10/100
# 0s - loss: 0.0277
# Epoch 11/100
# 0s - loss: 0.0310
# Epoch 12/100
# 0s - loss: 0.0280
# Epoch 13/100
# 0s - loss: 0.0288
# Epoch 14/100
# 0s - loss: 0.0262
# Epoch 15/100
# 0s - loss: 0.0280
# Epoch 16/100
# 0s - loss: 0.0293
# Epoch 17/100
# 0s - loss: 0.0271
# Epoch 18/100
# 0s - loss: 0.0239
# Epoch 19/100
# 0s - loss: 0.0260
# Epoch 20/100
# 0s - loss: 0.0251
# Epoch 21/100
# 0s - loss: 0.0254
# Epoch 22/100
# 0s - loss: 0.0257
# Epoch 23/100
# 0s - loss: 0.0217
# Epoch 24/100
# 0s - loss: 0.0234
# Epoch 25/100
# 0s - loss: 0.0225
# Epoch 26/100
# 0s - loss: 0.0208
# Epoch 27/100
# 0s - loss: 0.0241
# Epoch 28/100
# 0s - loss: 0.0210
# Epoch 29/100
# 0s - loss: 0.0226
# Epoch 30/100
# 0s - loss: 0.0220
# Epoch 31/100
# 0s - loss: 0.0213
# Epoch 32/100
# 0s - loss: 0.0208
# Epoch 33/100
# 0s - loss: 0.0205
# Epoch 34/100
# 0s - loss: 0.0229
# Epoch 35/100
# 0s - loss: 0.0172
# Epoch 36/100
# 0s - loss: 0.0194
# Epoch 37/100
# 0s - loss: 0.0207
# Epoch 38/100
# 0s - loss: 0.0183
# Epoch 39/100
# 0s - loss: 0.0199
# Epoch 40/100
# 0s - loss: 0.0163
# Epoch 41/100
# 0s - loss: 0.0180
# Epoch 42/100
# 0s - loss: 0.0213
# Epoch 43/100
# 0s - loss: 0.0199
# Epoch 44/100
# 0s - loss: 0.0194
# Epoch 45/100
# 0s - loss: 0.0203
# Epoch 46/100
# 0s - loss: 0.0194
# Epoch 47/100
# 0s - loss: 0.0190
# Epoch 48/100
# 0s - loss: 0.0189
# Epoch 49/100
# 0s - loss: 0.0167
# Epoch 50/100
# 0s - loss: 0.0196
# Epoch 51/100
# 0s - loss: 0.0166
# Epoch 52/100
# 0s - loss: 0.0198
# Epoch 53/100
# 0s - loss: 0.0175
# Epoch 54/100
# 0s - loss: 0.0188
# Epoch 55/100
# 0s - loss: 0.0148
# Epoch 56/100
# 0s - loss: 0.0187
# Epoch 57/100
# 0s - loss: 0.0177
# Epoch 58/100
# 0s - loss: 0.0165
# Epoch 59/100
# 0s - loss: 0.0163
# Epoch 60/100
# 0s - loss: 0.0175
# Epoch 61/100
# 0s - loss: 0.0152
# Epoch 62/100
# 0s - loss: 0.0156
# Epoch 63/100
# 0s - loss: 0.0182
# Epoch 64/100
# 0s - loss: 0.0133
# Epoch 65/100
# 0s - loss: 0.0137
# Epoch 66/100
# 0s - loss: 0.0158
# Epoch 67/100
# 0s - loss: 0.0147
# Epoch 68/100
# 0s - loss: 0.0175
# Epoch 69/100
# 0s - loss: 0.0178
# Epoch 70/100
# 0s - loss: 0.0166
# Epoch 71/100
# 0s - loss: 0.0122
# Epoch 72/100
# 0s - loss: 0.0166
# Epoch 73/100
# 0s - loss: 0.0149
# Epoch 74/100
# 0s - loss: 0.0150
# Epoch 75/100
# 0s - loss: 0.0129
# Epoch 76/100
# 0s - loss: 0.0131
# Epoch 77/100
# 0s - loss: 0.0147
# Epoch 78/100
# 0s - loss: 0.0151
# Epoch 79/100
# 0s - loss: 0.0124
# Epoch 80/100
# 0s - loss: 0.0141
# Epoch 81/100
# 0s - loss: 0.0179
# Epoch 82/100
# 0s - loss: 0.0150
# Epoch 83/100
# 0s - loss: 0.0145
# Epoch 84/100
# 0s - loss: 0.0149
# Epoch 85/100
# 0s - loss: 0.0148
# Epoch 86/100
# 0s - loss: 0.0162
# Epoch 87/100
# 0s - loss: 0.0134
# Epoch 88/100
# 0s - loss: 0.0146
# Epoch 89/100
# 0s - loss: 0.0147
# Epoch 90/100
# 0s - loss: 0.0161
# Epoch 91/100
# 0s - loss: 0.0142
# Epoch 92/100
# 0s - loss: 0.0146
# Epoch 93/100
# 0s - loss: 0.0130
# Epoch 94/100
# 0s - loss: 0.0134
# Epoch 95/100
# 0s - loss: 0.0152
# Epoch 96/100
# 0s - loss: 0.0137
# Epoch 97/100
# 0s - loss: 0.0168
# Epoch 98/100
# 0s - loss: 0.0129
# Epoch 99/100
# 0s - loss: 0.0115
# Epoch 100/100
# 0s - loss: 0.0134

# %%
plt.plot(np.array(df_nn_resid.iloc[:, -1]), label='Resid')
plt.plot(nn_resid.predict(np.array(df_nn_resid.iloc[:, :-1])), label='Forecast')
plt.legend(bbox_to_anchor=(1.36,1), loc='best')
plt.show()

# %%
nn_scaled_resid_forecast = nn_predict_series(nn_resid, 
                                      last_lags_resid_df_for_nn(resids_arima, test, lags_nn), 
                                      len(test))

nn_resids_forecast = scaler_back(nn_scaled_resid_forecast, scaler(resids_arima)[1], scaler(resids_arima)[2])

hybrid_forecast = hybrid_predict_series(forc_arima, nn_resids_forecast)

# %%
hybrid_plot_forecast(forc_arima, nn_resids_forecast, test)

# %%
errors_out_sample(test, hybrid_forecast)
# Out:
# {'MAE': 1.8767258926314743, 'MSE': 3.9724706265821035}

# %%
nn_resids_forecast
# Out:
# array([-0.73627406, -0.70612919, -0.63365126, -0.6071232 , -0.58183253,
#        -0.56641519, -0.55412376, -0.54529291, -0.53845406], dtype=float32)

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # Household consumption expenditures (for services)

# %%
hh_consump_serv = df.iloc[58, 1:186].copy()
hh_consump_serv.index = pd.DatetimeIndex(start='1969-01', end='2015-04', freq='Q')

# %%
plt.plot([np.log(i) for i in hh_consump_serv.tolist()])

# %%
test_stationarity(hh_consump_serv)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   0.742798
# p-value                          0.990654
# #Lags Used                       6.000000
# Number of Observations Used    178.000000
# Critical Value (5%)             -2.877918
# Critical Value (10%)            -2.575501
# Critical Value (1%)             -3.467632
# dtype: float64

# %%
test_stationarity(diff_series(hh_consump_serv))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -3.408599
# p-value                          0.010669
# #Lags Used                       5.000000
# Number of Observations Used    178.000000
# Critical Value (5%)             -2.877918
# Critical Value (10%)            -2.575501
# Critical Value (1%)             -3.467632
# dtype: float64

# %%
train = hh_consump_serv[:-9]
test = hh_consump_serv[-9:]

# %% [markdown]
# ### ARIMA

# %%
correlogram(diff_series(train))

# %%
arima_model = ARIMA(np.array(train), order=(2,1,1)).fit(trend='nc')
print(arima_model.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                  175
# Model:                 ARIMA(2, 1, 1)   Log Likelihood                  12.017
# Method:                       css-mle   S.D. of innovations              0.224
# Date:                Sun, 29 Jan 2017   AIC                            -16.035
# Time:                        03:02:23   BIC                             -3.375
# Sample:                             1   HQIC                           -10.900
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# ar.L1.D.y      1.5426      0.081     18.969      0.000         1.383     1.702
# ar.L2.D.y     -0.5439      0.080     -6.782      0.000        -0.701    -0.387
# ma.L1.D.y     -0.9411      0.045    -21.131      0.000        -1.028    -0.854
#                                     Roots
# =============================================================================
#                  Real           Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0030           +0.0000j            1.0030            0.0000
# AR.2            1.8331           +0.0000j            1.8331            0.0000
# MA.1            1.0625           +0.0000j            1.0625            0.0000
# -----------------------------------------------------------------------------

# %%
arima_model.plot_predict()
plt.show()

# %%
forc_arima = arima_model.forecast(len(test))
plot_forecast_out_only(test, forc_arima, bbox_loc=(1.03,1))

# %%
errors_out_sample(test, forc_arima[0])
# Out:
# {'MAE': 1.4200086097808855, 'MSE': 2.6485361131968301}

# %% [markdown]
# ### ANN

# %%
scaled_train = scaler(train)[0]

lags_for_nn = 2

train_nn = create_df_for_nn(scaled_train, lags_for_nn)

def assemble_model(n_lags):
    model = Sequential()
    # Layers
    model.add(Dense(10, input_dim=n_lags, activation='sigmoid'))
    model.add(Dense(10, input_dim=10, activation='sigmoid'))
    model.add(Dropout(0.5))
    model.add(Dense(10, input_dim=10, activation='sigmoid'))
    model.add(Dense(1, input_dim=10))
    # Compilation
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

nn = assemble_model(lags_for_nn)
nn.fit(np.array(train_nn.iloc[:, :-1]), 
       np.array(train_nn.iloc[:, -1]), 
       nb_epoch=100, 
       verbose=2,
       batch_size=1)
# Out:
# Epoch 1/100
# 1s - loss: 0.2817
# Epoch 2/100
# 0s - loss: 0.1154
# Epoch 3/100
# 0s - loss: 0.1260
# Epoch 4/100
# 0s - loss: 0.1070
# Epoch 5/100
# 0s - loss: 0.1099
# Epoch 6/100
# 0s - loss: 0.1092
# Epoch 7/100
# 0s - loss: 0.0997
# Epoch 8/100
# 0s - loss: 0.0961
# Epoch 9/100
# 0s - loss: 0.0947
# Epoch 10/100
# 0s - loss: 0.0934
# Epoch 11/100
# 0s - loss: 0.0901
# Epoch 12/100
# 0s - loss: 0.0861
# Epoch 13/100
# 0s - loss: 0.0703
# Epoch 14/100
# 0s - loss: 0.0627
# Epoch 15/100
# 0s - loss: 0.0539
# Epoch 16/100
# 0s - loss: 0.0533
# Epoch 17/100
# 0s - loss: 0.0412
# Epoch 18/100
# 0s - loss: 0.0431
# Epoch 19/100
# 0s - loss: 0.0407
# Epoch 20/100
# 0s - loss: 0.0312
# Epoch 21/100
# 0s - loss: 0.0311
# Epoch 22/100
# 0s - loss: 0.0287
# Epoch 23/100
# 0s - loss: 0.0257
# Epoch 24/100
# 0s - loss: 0.0295
# Epoch 25/100
# 0s - loss: 0.0260
# Epoch 26/100
# 0s - loss: 0.0228
# Epoch 27/100
# 0s - loss: 0.0246
# Epoch 28/100
# 0s - loss: 0.0211
# Epoch 29/100
# 0s - loss: 0.0213
# Epoch 30/100
# 0s - loss: 0.0210
# Epoch 31/100
# 0s - loss: 0.0198
# Epoch 32/100
# 0s - loss: 0.0182
# Epoch 33/100
# 0s - loss: 0.0222
# Epoch 34/100
# 0s - loss: 0.0224
# Epoch 35/100
# 0s - loss: 0.0193
# Epoch 36/100
# 0s - loss: 0.0207
# Epoch 37/100
# 0s - loss: 0.0227
# Epoch 38/100
# 0s - loss: 0.0152
# Epoch 39/100
# 0s - loss: 0.0169
# Epoch 40/100
# 0s - loss: 0.0180
# Epoch 41/100
# 0s - loss: 0.0131
# Epoch 42/100
# 0s - loss: 0.0161
# Epoch 43/100
# 0s - loss: 0.0172
# Epoch 44/100
# 0s - loss: 0.0146
# Epoch 45/100
# 0s - loss: 0.0105
# Epoch 46/100
# 0s - loss: 0.0126
# Epoch 47/100
# 0s - loss: 0.0154
# Epoch 48/100
# 0s - loss: 0.0173
# Epoch 49/100
# 0s - loss: 0.0171
# Epoch 50/100
# 0s - loss: 0.0172
# Epoch 51/100
# 0s - loss: 0.0120
# Epoch 52/100
# 0s - loss: 0.0165
# Epoch 53/100
# 0s - loss: 0.0125
# Epoch 54/100
# 0s - loss: 0.0104
# Epoch 55/100
# 0s - loss: 0.0111
# Epoch 56/100
# 0s - loss: 0.0139
# Epoch 57/100
# 0s - loss: 0.0115
# Epoch 58/100
# 0s - loss: 0.0130
# Epoch 59/100
# 0s - loss: 0.0126
# Epoch 60/100
# 0s - loss: 0.0145
# Epoch 61/100
# 0s - loss: 0.0098
# Epoch 62/100
# 0s - loss: 0.0115
# Epoch 63/100
# 0s - loss: 0.0125
# Epoch 64/100
# 0s - loss: 0.0106
# Epoch 65/100
# 0s - loss: 0.0123
# Epoch 66/100
# 0s - loss: 0.0150
# Epoch 67/100
# 0s - loss: 0.0115
# Epoch 68/100
# 0s - loss: 0.0098
# Epoch 69/100
# 0s - loss: 0.0135
# Epoch 70/100
# 0s - loss: 0.0120
# Epoch 71/100
# 0s - loss: 0.0117
# Epoch 72/100
# 0s - loss: 0.0148
# Epoch 73/100
# 0s - loss: 0.0133
# Epoch 74/100
# 0s - loss: 0.0085
# Epoch 75/100
# 0s - loss: 0.0116
# Epoch 76/100
# 0s - loss: 0.0090
# Epoch 77/100
# 0s - loss: 0.0090
# Epoch 78/100
# 0s - loss: 0.0084
# Epoch 79/100
# 0s - loss: 0.0120
# Epoch 80/100
# 0s - loss: 0.0116
# Epoch 81/100
# 0s - loss: 0.0087
# Epoch 82/100
# 0s - loss: 0.0134
# Epoch 83/100
# 0s - loss: 0.0070
# Epoch 84/100
# 0s - loss: 0.0090
# Epoch 85/100
# 0s - loss: 0.0089
# Epoch 86/100
# 0s - loss: 0.0100
# Epoch 87/100
# 0s - loss: 0.0095
# Epoch 88/100
# 0s - loss: 0.0082
# Epoch 89/100
# 0s - loss: 0.0084
# Epoch 90/100
# 0s - loss: 0.0119
# Epoch 91/100
# 0s - loss: 0.0098
# Epoch 92/100
# 0s - loss: 0.0090
# Epoch 93/100
# 0s - loss: 0.0112
# Epoch 94/100
# 0s - loss: 0.0076
# Epoch 95/100
# 0s - loss: 0.0094
# Epoch 96/100
# 0s - loss: 0.0088
# Epoch 97/100
# 0s - loss: 0.0091
# Epoch 98/100
# 0s - loss: 0.0087
# Epoch 99/100
# 0s - loss: 0.0090
# Epoch 100/100
# 0s - loss: 0.0076

# %%
nn_plot_in_sample(nn, train_nn, bbox_loc=(1.45,1))

# %%
nn_scaled_forecast = nn_predict_series(nn, 
                                      last_obs_creator_nn(train_nn, lags_for_nn), 
                                      len(test))
nn_forecast = scaler_back(nn_scaled_forecast, scaler(train)[1], scaler(train)[2])

nn_plot_out_sample(nn_forecast, test, bbox_loc=(1.43,1))

# %%
errors_out_sample(test, nn_forecast)
# Out:
# {'MAE': 7.2130879855685777, 'MSE': 54.552444802981682}

# %% [markdown]
# ### Hybrid

# %%
resids_arima = get_resids_arima(train, arima_model)
plt.plot(resids_arima)
plt.show()

# %%
scaled_resids_arima = scaler(resids_arima)[0]

lags_nn = 2

df_nn_resid = create_df_for_nn_residuals(scaled_resids_arima[1:], lags_nn)

def assemble_model(n_lags):
    model = Sequential()
    # Layers
    model.add(Dense(10, input_dim=n_lags, activation='sigmoid'))
    model.add(Dropout(0.5))
    model.add(Dense(10, input_dim=10, activation='sigmoid'))
    model.add(Dense(1, input_dim=10))
    # Compilation
    model.compile(loss='mean_squared_error', optimizer='adam')
    return(model)

nn_resid = assemble_model(lags_nn)
nn_resid.fit(np.array(df_nn_resid.iloc[:, :-1]), 
       np.array(df_nn_resid.iloc[:, -1]), 
       nb_epoch=100, 
       verbose=2,
       batch_size=1)
# Out:
# Epoch 1/100
# 0s - loss: 0.0527
# Epoch 2/100
# 0s - loss: 0.0362
# Epoch 3/100
# 0s - loss: 0.0401
# Epoch 4/100
# 0s - loss: 0.0331
# Epoch 5/100
# 0s - loss: 0.0315
# Epoch 6/100
# 0s - loss: 0.0322
# Epoch 7/100
# 0s - loss: 0.0305
# Epoch 8/100
# 0s - loss: 0.0293
# Epoch 9/100
# 0s - loss: 0.0309
# Epoch 10/100
# 0s - loss: 0.0290
# Epoch 11/100
# 0s - loss: 0.0279
# Epoch 12/100
# 0s - loss: 0.0318
# Epoch 13/100
# 0s - loss: 0.0312
# Epoch 14/100
# 0s - loss: 0.0305
# Epoch 15/100
# 0s - loss: 0.0300
# Epoch 16/100
# 0s - loss: 0.0292
# Epoch 17/100
# 0s - loss: 0.0299
# Epoch 18/100
# 0s - loss: 0.0301
# Epoch 19/100
# 0s - loss: 0.0300
# Epoch 20/100
# 0s - loss: 0.0292
# Epoch 21/100
# 0s - loss: 0.0287
# Epoch 22/100
# 0s - loss: 0.0309
# Epoch 23/100
# 0s - loss: 0.0301
# Epoch 24/100
# 0s - loss: 0.0295
# Epoch 25/100
# 0s - loss: 0.0263
# Epoch 26/100
# 0s - loss: 0.0269
# Epoch 27/100
# 0s - loss: 0.0266
# Epoch 28/100
# 0s - loss: 0.0268
# Epoch 29/100
# 0s - loss: 0.0268
# Epoch 30/100
# 0s - loss: 0.0253
# Epoch 31/100
# 0s - loss: 0.0269
# Epoch 32/100
# 0s - loss: 0.0283
# Epoch 33/100
# 0s - loss: 0.0240
# Epoch 34/100
# 0s - loss: 0.0273
# Epoch 35/100
# 0s - loss: 0.0264
# Epoch 36/100
# 0s - loss: 0.0270
# Epoch 37/100
# 0s - loss: 0.0210
# Epoch 38/100
# 0s - loss: 0.0258
# Epoch 39/100
# 0s - loss: 0.0264
# Epoch 40/100
# 0s - loss: 0.0261
# Epoch 41/100
# 0s - loss: 0.0235
# Epoch 42/100
# 0s - loss: 0.0262
# Epoch 43/100
# 0s - loss: 0.0247
# Epoch 44/100
# 0s - loss: 0.0257
# Epoch 45/100
# 0s - loss: 0.0213
# Epoch 46/100
# 0s - loss: 0.0220
# Epoch 47/100
# 0s - loss: 0.0233
# Epoch 48/100
# 0s - loss: 0.0240
# Epoch 49/100
# 0s - loss: 0.0267
# Epoch 50/100
# 0s - loss: 0.0256
# Epoch 51/100
# 0s - loss: 0.0232
# Epoch 52/100
# 0s - loss: 0.0250
# Epoch 53/100
# 0s - loss: 0.0231
# Epoch 54/100
# 0s - loss: 0.0229
# Epoch 55/100
# 0s - loss: 0.0253
# Epoch 56/100
# 0s - loss: 0.0202
# Epoch 57/100
# 0s - loss: 0.0246
# Epoch 58/100
# 0s - loss: 0.0216
# Epoch 59/100
# 0s - loss: 0.0229
# Epoch 60/100
# 0s - loss: 0.0225
# Epoch 61/100
# 0s - loss: 0.0193
# Epoch 62/100
# 0s - loss: 0.0217
# Epoch 63/100
# 0s - loss: 0.0226
# Epoch 64/100
# 0s - loss: 0.0219
# Epoch 65/100
# 0s - loss: 0.0215
# Epoch 66/100
# 0s - loss: 0.0228
# Epoch 67/100
# 0s - loss: 0.0229
# Epoch 68/100
# 0s - loss: 0.0215
# Epoch 69/100
# 0s - loss: 0.0244
# Epoch 70/100
# 0s - loss: 0.0233
# Epoch 71/100
# 0s - loss: 0.0233
# Epoch 72/100
# 0s - loss: 0.0203
# Epoch 73/100
# 0s - loss: 0.0209
# Epoch 74/100
# 0s - loss: 0.0186
# Epoch 75/100
# 0s - loss: 0.0214
# Epoch 76/100
# 0s - loss: 0.0224
# Epoch 77/100
# 0s - loss: 0.0208
# Epoch 78/100
# 0s - loss: 0.0214
# Epoch 79/100
# 0s - loss: 0.0224
# Epoch 80/100
# 0s - loss: 0.0208
# Epoch 81/100
# 0s - loss: 0.0239
# Epoch 82/100
# 0s - loss: 0.0210
# Epoch 83/100
# 0s - loss: 0.0202
# Epoch 84/100
# 0s - loss: 0.0190
# Epoch 85/100
# 0s - loss: 0.0197
# Epoch 86/100
# 0s - loss: 0.0209
# Epoch 87/100
# 0s - loss: 0.0199
# Epoch 88/100
# 0s - loss: 0.0207
# Epoch 89/100
# 0s - loss: 0.0208
# Epoch 90/100
# 0s - loss: 0.0233
# Epoch 91/100
# 0s - loss: 0.0217
# Epoch 92/100
# 0s - loss: 0.0217
# Epoch 93/100
# 0s - loss: 0.0199
# Epoch 94/100
# 0s - loss: 0.0201
# Epoch 95/100
# 0s - loss: 0.0202
# Epoch 96/100
# 0s - loss: 0.0228
# Epoch 97/100
# 0s - loss: 0.0213
# Epoch 98/100
# 0s - loss: 0.0202
# Epoch 99/100
# 0s - loss: 0.0225
# Epoch 100/100
# 0s - loss: 0.0196

# %%
plt.plot(np.array(df_nn_resid.iloc[:, -1]), label='Resid')
plt.plot(nn_resid.predict(np.array(df_nn_resid.iloc[:, :-1])), label='Forecast')
plt.legend(bbox_to_anchor=(1.36,1), loc='best')
plt.show()

# %%
nn_scaled_resid_forecast = nn_predict_series(nn_resid, 
                                      last_lags_resid_df_for_nn(resids_arima, test, lags_nn), 
                                      len(test))

nn_resids_forecast = scaler_back(nn_scaled_resid_forecast, scaler(resids_arima)[1], scaler(resids_arima)[2])

hybrid_forecast = hybrid_predict_series(forc_arima, nn_resids_forecast)

# %%
hybrid_plot_forecast(forc_arima, nn_resids_forecast, test)

# %%
errors_out_sample(test, hybrid_forecast)
# Out:
# {'MAE': 1.9576776558384807, 'MSE': 4.3745460538132948}

# %%
nn_resids_forecast
# Out:
# array([-0.676898  , -0.63642812, -0.57251853, -0.54108268, -0.51261252,
#        -0.49351907, -0.47856379, -0.46775252, -0.4596462 ], dtype=float32)

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # Saving and Investment by Sector

# %%
sav_inv_sec = df.iloc[63, 1:186].copy()
sav_inv_sec.index = pd.DatetimeIndex(start='1969-01', end='2015-04', freq='Q')

# %%
plt.plot([np.log(i) for i in sav_inv_sec.tolist()])

# %%
test_stationarity(sav_inv_sec)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   1.153398
# p-value                          0.995648
# #Lags Used                      14.000000
# Number of Observations Used    170.000000
# Critical Value (5%)             -2.878696
# Critical Value (10%)            -2.575917
# Critical Value (1%)             -3.469413
# dtype: float64

# %%
test_stationarity(diff_series(sav_inv_sec))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -4.325188
# p-value                          0.000402
# #Lags Used                       3.000000
# Number of Observations Used    180.000000
# Critical Value (5%)             -2.877735
# Critical Value (10%)            -2.575403
# Critical Value (1%)             -3.467211
# dtype: float64

# %%
train = sav_inv_sec[:-9]
test = sav_inv_sec[-9:]

# %% [markdown]
# ### ARIMA

# %%
correlogram(diff_series(train))

# %%
arima_model = ARIMA(np.array(train), order=(1,1,1)).fit(trend='c')
print(arima_model.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                  175
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -922.201
# Method:                       css-mle   S.D. of innovations             47.011
# Date:                Sun, 29 Jan 2017   AIC                           1852.403
# Time:                        03:24:25   BIC                           1865.062
# Sample:                             1   HQIC                          1857.538
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const         16.4022      6.765      2.425      0.016         3.144    29.661
# ar.L1.D.y      0.7943      0.094      8.475      0.000         0.611     0.978
# ma.L1.D.y     -0.6044      0.110     -5.486      0.000        -0.820    -0.388
#                                     Roots
# =============================================================================
#                  Real           Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.2589           +0.0000j            1.2589            0.0000
# MA.1            1.6544           +0.0000j            1.6544            0.0000
# -----------------------------------------------------------------------------

# %%
arima_model.plot_predict()
plt.show()

# %%
forc_arima = arima_model.forecast(len(test))
plot_forecast_out_only(test, forc_arima, bbox_loc=(1.03,1))

# %%
errors_out_sample(test, forc_arima[0])
# Out:
# {'MAE': 45.118882096290839, 'MSE': 4046.4860340727191}

# %% [markdown]
# ### ANN

# %%
scaled_train = scaler(train)[0]

lags_for_nn = 2

train_nn = create_df_for_nn(scaled_train, lags_for_nn)

def assemble_model(n_lags):
    model = Sequential()
    # Layers
    model.add(Dense(10, input_dim=n_lags, activation='sigmoid'))
    model.add(Dense(10, input_dim=10, activation='sigmoid'))
    model.add(Dropout(0.5))
    model.add(Dense(10, input_dim=10, activation='sigmoid'))
    model.add(Dense(1, input_dim=10))
    # Compilation
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

nn = assemble_model(lags_for_nn)
nn.fit(np.array(train_nn.iloc[:, :-1]), 
       np.array(train_nn.iloc[:, -1]), 
       nb_epoch=100, 
       verbose=2,
       batch_size=1)
# Out:
# Epoch 1/100
# 0s - loss: 0.1047
# Epoch 2/100
# 0s - loss: 0.0930
# Epoch 3/100
# 0s - loss: 0.0911
# Epoch 4/100
# 0s - loss: 0.0803
# Epoch 5/100
# 0s - loss: 0.0836
# Epoch 6/100
# 0s - loss: 0.0799
# Epoch 7/100
# 0s - loss: 0.0768
# Epoch 8/100
# 0s - loss: 0.0793
# Epoch 9/100
# 0s - loss: 0.0749
# Epoch 10/100
# 0s - loss: 0.0715
# Epoch 11/100
# 0s - loss: 0.0689
# Epoch 12/100
# 0s - loss: 0.0669
# Epoch 13/100
# 0s - loss: 0.0555
# Epoch 14/100
# 0s - loss: 0.0497
# Epoch 15/100
# 0s - loss: 0.0433
# Epoch 16/100
# 0s - loss: 0.0300
# Epoch 17/100
# 0s - loss: 0.0364
# Epoch 18/100
# 0s - loss: 0.0215
# Epoch 19/100
# 0s - loss: 0.0288
# Epoch 20/100
# 0s - loss: 0.0225
# Epoch 21/100
# 0s - loss: 0.0245
# Epoch 22/100
# 0s - loss: 0.0263
# Epoch 23/100
# 0s - loss: 0.0207
# Epoch 24/100
# 0s - loss: 0.0210
# Epoch 25/100
# 0s - loss: 0.0167
# Epoch 26/100
# 0s - loss: 0.0170
# Epoch 27/100
# 0s - loss: 0.0197
# Epoch 28/100
# 0s - loss: 0.0257
# Epoch 29/100
# 0s - loss: 0.0210
# Epoch 30/100
# 0s - loss: 0.0202
# Epoch 31/100
# 0s - loss: 0.0184
# Epoch 32/100
# 0s - loss: 0.0146
# Epoch 33/100
# 0s - loss: 0.0202
# Epoch 34/100
# 0s - loss: 0.0176
# Epoch 35/100
# 0s - loss: 0.0171
# Epoch 36/100
# 0s - loss: 0.0185
# Epoch 37/100
# 0s - loss: 0.0150
# Epoch 38/100
# 0s - loss: 0.0154
# Epoch 39/100
# 0s - loss: 0.0142
# Epoch 40/100
# 0s - loss: 0.0169
# Epoch 41/100
# 0s - loss: 0.0119
# Epoch 42/100
# 0s - loss: 0.0124
# Epoch 43/100
# 0s - loss: 0.0158
# Epoch 44/100
# 0s - loss: 0.0163
# Epoch 45/100
# 0s - loss: 0.0169
# Epoch 46/100
# 0s - loss: 0.0157
# Epoch 47/100
# 0s - loss: 0.0142
# Epoch 48/100
# 0s - loss: 0.0132
# Epoch 49/100
# 0s - loss: 0.0132
# Epoch 50/100
# 0s - loss: 0.0148
# Epoch 51/100
# 0s - loss: 0.0095
# Epoch 52/100
# 0s - loss: 0.0131
# Epoch 53/100
# 0s - loss: 0.0135
# Epoch 54/100
# 0s - loss: 0.0137
# Epoch 55/100
# 0s - loss: 0.0121
# Epoch 56/100
# 0s - loss: 0.0150
# Epoch 57/100
# 0s - loss: 0.0128
# Epoch 58/100
# 0s - loss: 0.0122
# Epoch 59/100
# 0s - loss: 0.0139
# Epoch 60/100
# 0s - loss: 0.0130
# Epoch 61/100
# 0s - loss: 0.0097
# Epoch 62/100
# 0s - loss: 0.0127
# Epoch 63/100
# 0s - loss: 0.0138
# Epoch 64/100
# 0s - loss: 0.0119
# Epoch 65/100
# 0s - loss: 0.0099
# Epoch 66/100
# 0s - loss: 0.0102
# Epoch 67/100
# 0s - loss: 0.0109
# Epoch 68/100
# 0s - loss: 0.0123
# Epoch 69/100
# 0s - loss: 0.0098
# Epoch 70/100
# 0s - loss: 0.0097
# Epoch 71/100
# 0s - loss: 0.0120
# Epoch 72/100
# 0s - loss: 0.0115
# Epoch 73/100
# 0s - loss: 0.0115
# Epoch 74/100
# 0s - loss: 0.0093
# Epoch 75/100
# 0s - loss: 0.0092
# Epoch 76/100
# 0s - loss: 0.0118
# Epoch 77/100
# 0s - loss: 0.0088
# Epoch 78/100
# 0s - loss: 0.0122
# Epoch 79/100
# 0s - loss: 0.0085
# Epoch 80/100
# 0s - loss: 0.0098
# Epoch 81/100
# 0s - loss: 0.0128
# Epoch 82/100
# 0s - loss: 0.0116
# Epoch 83/100
# 0s - loss: 0.0112
# Epoch 84/100
# 0s - loss: 0.0107
# Epoch 85/100
# 0s - loss: 0.0121
# Epoch 86/100
# 0s - loss: 0.0093
# Epoch 87/100
# 0s - loss: 0.0091
# Epoch 88/100
# 0s - loss: 0.0086
# Epoch 89/100
# 0s - loss: 0.0111
# Epoch 90/100
# 0s - loss: 0.0074
# Epoch 91/100
# 0s - loss: 0.0076
# Epoch 92/100
# 0s - loss: 0.0105
# Epoch 93/100
# 0s - loss: 0.0106
# Epoch 94/100
# 0s - loss: 0.0077
# Epoch 95/100
# 0s - loss: 0.0090
# Epoch 96/100
# 0s - loss: 0.0089
# Epoch 97/100
# 0s - loss: 0.0146
# Epoch 98/100
# 0s - loss: 0.0104
# Epoch 99/100
# 0s - loss: 0.0084
# Epoch 100/100
# 0s - loss: 0.0100

# %%
nn_plot_in_sample(nn, train_nn, bbox_loc=(1.45,1))

# %%
nn_scaled_forecast = nn_predict_series(nn, 
                                      last_obs_creator_nn(train_nn, lags_for_nn), 
                                      len(test))
nn_forecast = scaler_back(nn_scaled_forecast, scaler(train)[1], scaler(train)[2])

nn_plot_out_sample(nn_forecast, test, bbox_loc=(1.43,1))

# %%
errors_out_sample(test, nn_forecast)
# Out:
# {'MAE': 808.18125542534733, 'MSE': 669951.27567990497}

# %% [markdown]
# ### Hybrid

# %%
resids_arima = get_resids_arima(train, arima_model)
plt.plot(resids_arima)
plt.show()

# %%
scaled_resids_arima = scaler(resids_arima)[0]

lags_nn = 2

df_nn_resid = create_df_for_nn_residuals(scaled_resids_arima[1:], lags_nn)

def assemble_model(n_lags):
    model = Sequential()
    # Layers
    model.add(Dense(10, input_dim=n_lags, activation='sigmoid'))
    model.add(Dropout(0.5))
    model.add(Dense(10, input_dim=10, activation='sigmoid'))
    model.add(Dropout(0.5))
    model.add(Dense(1, input_dim=10))
    # Compilation
    model.compile(loss='mean_squared_error', optimizer='adam')
    return(model)

nn_resid = assemble_model(lags_nn)
nn_resid.fit(np.array(df_nn_resid.iloc[:, :-1]), 
       np.array(df_nn_resid.iloc[:, -1]), 
       nb_epoch=100, 
       verbose=2,
       batch_size=1)
# Out:
# Epoch 1/100
# 0s - loss: 0.2967
# Epoch 2/100
# 0s - loss: 0.2027
# Epoch 3/100
# 0s - loss: 0.1280
# Epoch 4/100
# 0s - loss: 0.1102
# Epoch 5/100
# 0s - loss: 0.0991
# Epoch 6/100
# 0s - loss: 0.0599
# Epoch 7/100
# 0s - loss: 0.0624
# Epoch 8/100
# 0s - loss: 0.0499
# Epoch 9/100
# 0s - loss: 0.0422
# Epoch 10/100
# 0s - loss: 0.0419
# Epoch 11/100
# 0s - loss: 0.0374
# Epoch 12/100
# 0s - loss: 0.0347
# Epoch 13/100
# 0s - loss: 0.0302
# Epoch 14/100
# 0s - loss: 0.0318
# Epoch 15/100
# 0s - loss: 0.0296
# Epoch 16/100
# 0s - loss: 0.0287
# Epoch 17/100
# 0s - loss: 0.0255
# Epoch 18/100
# 0s - loss: 0.0236
# Epoch 19/100
# 0s - loss: 0.0283
# Epoch 20/100
# 0s - loss: 0.0232
# Epoch 21/100
# 0s - loss: 0.0252
# Epoch 22/100
# 0s - loss: 0.0244
# Epoch 23/100
# 0s - loss: 0.0247
# Epoch 24/100
# 0s - loss: 0.0232
# Epoch 25/100
# 0s - loss: 0.0236
# Epoch 26/100
# 0s - loss: 0.0234
# Epoch 27/100
# 0s - loss: 0.0240
# Epoch 28/100
# 0s - loss: 0.0233
# Epoch 29/100
# 0s - loss: 0.0243
# Epoch 30/100
# 0s - loss: 0.0239
# Epoch 31/100
# 0s - loss: 0.0233
# Epoch 32/100
# 0s - loss: 0.0235
# Epoch 33/100
# 0s - loss: 0.0229
# Epoch 34/100
# 0s - loss: 0.0233
# Epoch 35/100
# 0s - loss: 0.0234
# Epoch 36/100
# 0s - loss: 0.0233
# Epoch 37/100
# 0s - loss: 0.0239
# Epoch 38/100
# 0s - loss: 0.0230
# Epoch 39/100
# 0s - loss: 0.0234
# Epoch 40/100
# 0s - loss: 0.0236
# Epoch 41/100
# 0s - loss: 0.0230
# Epoch 42/100
# 0s - loss: 0.0234
# Epoch 43/100
# 0s - loss: 0.0226
# Epoch 44/100
# 0s - loss: 0.0236
# Epoch 45/100
# 0s - loss: 0.0234
# Epoch 46/100
# 0s - loss: 0.0231
# Epoch 47/100
# 0s - loss: 0.0232
# Epoch 48/100
# 0s - loss: 0.0232
# Epoch 49/100
# 0s - loss: 0.0227
# Epoch 50/100
# 0s - loss: 0.0236
# Epoch 51/100
# 0s - loss: 0.0224
# Epoch 52/100
# 0s - loss: 0.0232
# Epoch 53/100
# 0s - loss: 0.0232
# Epoch 54/100
# 0s - loss: 0.0229
# Epoch 55/100
# 0s - loss: 0.0228
# Epoch 56/100
# 0s - loss: 0.0235
# Epoch 57/100
# 0s - loss: 0.0233
# Epoch 58/100
# 0s - loss: 0.0228
# Epoch 59/100
# 0s - loss: 0.0231
# Epoch 60/100
# 0s - loss: 0.0231
# Epoch 61/100
# 0s - loss: 0.0229
# Epoch 62/100
# 0s - loss: 0.0226
# Epoch 63/100
# 0s - loss: 0.0225
# Epoch 64/100
# 0s - loss: 0.0229
# Epoch 65/100
# 0s - loss: 0.0236
# Epoch 66/100
# 0s - loss: 0.0231
# Epoch 67/100
# 0s - loss: 0.0229
# Epoch 68/100
# 0s - loss: 0.0230
# Epoch 69/100
# 0s - loss: 0.0233
# Epoch 70/100
# 0s - loss: 0.0222
# Epoch 71/100
# 0s - loss: 0.0229
# Epoch 72/100
# 0s - loss: 0.0219
# Epoch 73/100
# 0s - loss: 0.0223
# Epoch 74/100
# 0s - loss: 0.0219
# Epoch 75/100
# 0s - loss: 0.0231
# Epoch 76/100
# 0s - loss: 0.0213
# Epoch 77/100
# 0s - loss: 0.0222
# Epoch 78/100
# 0s - loss: 0.0223
# Epoch 79/100
# 0s - loss: 0.0211
# Epoch 80/100
# 0s - loss: 0.0218
# Epoch 81/100
# 0s - loss: 0.0222
# Epoch 82/100
# 0s - loss: 0.0214
# Epoch 83/100
# 0s - loss: 0.0215
# Epoch 84/100
# 0s - loss: 0.0208
# Epoch 85/100
# 0s - loss: 0.0221
# Epoch 86/100
# 0s - loss: 0.0208
# Epoch 87/100
# 0s - loss: 0.0219
# Epoch 88/100
# 0s - loss: 0.0193
# Epoch 89/100
# 0s - loss: 0.0222
# Epoch 90/100
# 0s - loss: 0.0199
# Epoch 91/100
# 0s - loss: 0.0210
# Epoch 92/100
# 0s - loss: 0.0201
# Epoch 93/100
# 0s - loss: 0.0214
# Epoch 94/100
# 0s - loss: 0.0178
# Epoch 95/100
# 0s - loss: 0.0215
# Epoch 96/100
# 0s - loss: 0.0209
# Epoch 97/100
# 0s - loss: 0.0197
# Epoch 98/100
# 0s - loss: 0.0210
# Epoch 99/100
# 0s - loss: 0.0197
# Epoch 100/100
# 0s - loss: 0.0200

# %%
plt.plot(np.array(df_nn_resid.iloc[:, -1]), label='Resid')
plt.plot(nn_resid.predict(np.array(df_nn_resid.iloc[:, :-1])), label='Forecast')
plt.legend(bbox_to_anchor=(1.36,1), loc='best')
plt.show()

# %%
nn_scaled_resid_forecast = nn_predict_series(nn_resid, 
                                      last_lags_resid_df_for_nn(resids_arima, test, lags_nn), 
                                      len(test))

nn_resids_forecast = scaler_back(nn_scaled_resid_forecast, scaler(resids_arima)[1], scaler(resids_arima)[2])

hybrid_forecast = hybrid_predict_series(forc_arima, nn_resids_forecast)

# %%
hybrid_plot_forecast(forc_arima, nn_resids_forecast, test)

# %%
errors_out_sample(test, hybrid_forecast)
# Out:
# {'MAE': 36.300565424707457, 'MSE': 3094.9613101830473}

# %%
nn_resids_forecast
# Out:
# array([-28.95257187, -28.95257187, -18.09087372, -16.47313881,
#        -14.83150482, -14.42428493, -14.18290997, -14.1068716 , -14.07031441], dtype=float32)

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # GDP in billions of current dollars  (Seasonally adjusted annual rates)

# %%
US_GDP = df.iloc[67, 1:274].copy()
US_GDP.index = pd.DatetimeIndex(start='1947-01', end='2015-04', freq='Q')

# %%
plt.plot([np.log(i) for i in US_GDP.tolist()])

# %%
test_stationarity(US_GDP)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   3.354483
# p-value                          1.000000
# #Lags Used                      11.000000
# Number of Observations Used    261.000000
# Critical Value (1%)             -3.455656
# Critical Value (5%)             -2.872678
# Critical Value (10%)            -2.572705
# dtype: float64

# %%
test_stationarity(diff_series(US_GDP))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.720379
# p-value                          0.420644
# #Lags Used                      16.000000
# Number of Observations Used    255.000000
# Critical Value (1%)             -3.456257
# Critical Value (5%)             -2.872942
# Critical Value (10%)            -2.572846
# dtype: float64

# %%
test_stationarity(diff_series(diff_series(US_GDP)))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -6.915610e+00
# p-value                        1.181648e-09
# #Lags Used                     1.400000e+01
# Number of Observations Used    2.560000e+02
# Critical Value (1%)           -3.456155e+00
# Critical Value (5%)           -2.872897e+00
# Critical Value (10%)          -2.572822e+00
# dtype: float64

# %%
train = US_GDP[:-9]
test = US_GDP[-9:]

# %% [markdown]
# ### ARIMA

# %%
correlogram(diff_series(diff_series(train)))

# %%
arima_model = ARIMA(np.array(train), order=(2,2,1)).fit(trend='c')
print(arima_model.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                   D2.y   No. Observations:                  262
# Model:                 ARIMA(2, 2, 1)   Log Likelihood               -1357.383
# Method:                       css-mle   S.D. of innovations             42.696
# Date:                Tue, 31 Jan 2017   AIC                           2724.767
# Time:                        01:28:02   BIC                           2742.608
# Sample:                             2   HQIC                          2731.938
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          0.5865      0.086      6.812      0.000         0.418     0.755
# ar.L1.D2.y     0.4032      0.061      6.600      0.000         0.283     0.523
# ar.L2.D2.y     0.2031      0.061      3.324      0.001         0.083     0.323
# ma.L1.D2.y    -0.9999      0.011    -91.617      0.000        -1.021    -0.979
#                                     Roots
# =============================================================================
#                  Real           Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.4383           +0.0000j            1.4383            0.0000
# AR.2           -3.4238           +0.0000j            3.4238            0.5000
# MA.1            1.0001           +0.0000j            1.0001            0.0000
# -----------------------------------------------------------------------------

# %%
arima_model.plot_predict()
plt.show()

# %%
forc_arima = arima_model.forecast(len(test))
plot_forecast_out_only(test, forc_arima, bbox_loc=(1.03,1))

# %%
plot_forecast_out_only(test, forc_arima, bbox_loc=(1.03,1), conf_int=False)

# %%
errors_out_sample(test, forc_arima[0])
# Out:
# {'MAE': 191.99993071058594, 'MSE': 48816.477424064527}

# %% [markdown]
# ### ANN

# %%
scaled_train = scaler(train)[0]

lags_for_nn = 2

train_nn = create_df_for_nn(scaled_train, lags_for_nn)

def assemble_model(n_lags):
    model = Sequential()
    # Layers
    model.add(Dense(10, input_dim=n_lags, activation='sigmoid'))
    model.add(Dense(10, input_dim=10, activation='sigmoid'))
    model.add(Dense(10, input_dim=10, activation='sigmoid'))
    model.add(Dense(1, input_dim=10))
    # Compilation
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

nn = assemble_model(lags_for_nn)
nn.fit(np.array(train_nn.iloc[:, :-1]), 
       np.array(train_nn.iloc[:, -1]), 
       nb_epoch=100, 
       verbose=2,
       batch_size=1)
# Out:
# Epoch 1/100
# 0s - loss: 0.1228
# Epoch 2/100
# 0s - loss: 0.0935
# Epoch 3/100
# 0s - loss: 0.0858
# Epoch 4/100
# 0s - loss: 0.0688
# Epoch 5/100
# 0s - loss: 0.0433
# Epoch 6/100
# 0s - loss: 0.0149
# Epoch 7/100
# 0s - loss: 0.0026
# Epoch 8/100
# 0s - loss: 7.8511e-04
# Epoch 9/100
# 0s - loss: 5.9209e-04
# Epoch 10/100
# 0s - loss: 5.4384e-04
# Epoch 11/100
# 0s - loss: 4.6637e-04
# Epoch 12/100
# 0s - loss: 4.2530e-04
# Epoch 13/100
# 0s - loss: 3.7212e-04
# Epoch 14/100
# 0s - loss: 3.1819e-04
# Epoch 15/100
# 0s - loss: 3.0875e-04
# Epoch 16/100
# 0s - loss: 3.1168e-04
# Epoch 17/100
# 0s - loss: 2.8864e-04
# Epoch 18/100
# 0s - loss: 2.5198e-04
# Epoch 19/100
# 0s - loss: 2.6103e-04
# Epoch 20/100
# 0s - loss: 2.5283e-04
# Epoch 21/100
# 0s - loss: 2.6435e-04
# Epoch 22/100
# 0s - loss: 2.3605e-04
# Epoch 23/100
# 0s - loss: 2.3343e-04
# Epoch 24/100
# 0s - loss: 2.7943e-04
# Epoch 25/100
# 0s - loss: 2.4546e-04
# Epoch 26/100
# 0s - loss: 2.3312e-04
# Epoch 27/100
# 0s - loss: 2.1477e-04
# Epoch 28/100
# 0s - loss: 2.1806e-04
# Epoch 29/100
# 0s - loss: 2.3211e-04
# Epoch 30/100
# 0s - loss: 2.1959e-04
# Epoch 31/100
# 0s - loss: 2.1873e-04
# Epoch 32/100
# 0s - loss: 2.4418e-04
# Epoch 33/100
# 0s - loss: 2.1745e-04
# Epoch 34/100
# 0s - loss: 2.3130e-04
# Epoch 35/100
# 0s - loss: 2.1269e-04
# Epoch 36/100
# 0s - loss: 2.3283e-04
# Epoch 37/100
# 0s - loss: 1.8274e-04
# Epoch 38/100
# 0s - loss: 2.2696e-04
# Epoch 39/100
# 0s - loss: 2.1271e-04
# Epoch 40/100
# 0s - loss: 2.0430e-04
# Epoch 41/100
# 0s - loss: 2.0091e-04
# Epoch 42/100
# 0s - loss: 2.0227e-04
# Epoch 43/100
# 0s - loss: 1.8492e-04
# Epoch 44/100
# 0s - loss: 1.7304e-04
# Epoch 45/100
# 0s - loss: 1.7138e-04
# Epoch 46/100
# 0s - loss: 1.6826e-04
# Epoch 47/100
# 0s - loss: 2.0341e-04
# Epoch 48/100
# 0s - loss: 2.0980e-04
# Epoch 49/100
# 0s - loss: 2.0177e-04
# Epoch 50/100
# 0s - loss: 1.6072e-04
# Epoch 51/100
# 0s - loss: 1.7259e-04
# Epoch 52/100
# 0s - loss: 1.7811e-04
# Epoch 53/100
# 0s - loss: 1.5759e-04
# Epoch 54/100
# 0s - loss: 1.3341e-04
# Epoch 55/100
# 0s - loss: 1.6626e-04
# Epoch 56/100
# 0s - loss: 1.7399e-04
# Epoch 57/100
# 0s - loss: 1.7308e-04
# Epoch 58/100
# 0s - loss: 1.4735e-04
# Epoch 59/100
# 0s - loss: 1.3270e-04
# Epoch 60/100
# 0s - loss: 1.3938e-04
# Epoch 61/100
# 0s - loss: 1.5253e-04
# Epoch 62/100
# 0s - loss: 1.2536e-04
# Epoch 63/100
# 0s - loss: 1.3734e-04
# Epoch 64/100
# 0s - loss: 1.5803e-04
# Epoch 65/100
# 0s - loss: 1.4301e-04
# Epoch 66/100
# 0s - loss: 1.3454e-04
# Epoch 67/100
# 0s - loss: 1.4786e-04
# Epoch 68/100
# 0s - loss: 1.2315e-04
# Epoch 69/100
# 0s - loss: 1.2253e-04
# Epoch 70/100
# 0s - loss: 1.3619e-04
# Epoch 71/100
# 0s - loss: 1.3783e-04
# Epoch 72/100
# 0s - loss: 9.8899e-05
# Epoch 73/100
# 0s - loss: 1.1727e-04
# Epoch 74/100
# 0s - loss: 1.4581e-04
# Epoch 75/100
# 0s - loss: 1.1440e-04
# Epoch 76/100
# 0s - loss: 1.4252e-04
# Epoch 77/100
# 0s - loss: 1.1586e-04
# Epoch 78/100
# 0s - loss: 1.6823e-04
# Epoch 79/100
# 0s - loss: 1.4751e-04
# Epoch 80/100
# 0s - loss: 1.1668e-04
# Epoch 81/100
# 0s - loss: 1.4255e-04
# Epoch 82/100
# 0s - loss: 1.2325e-04
# Epoch 83/100
# 0s - loss: 1.1692e-04
# Epoch 84/100
# 0s - loss: 1.3000e-04
# Epoch 85/100
# 0s - loss: 1.0933e-04
# Epoch 86/100
# 0s - loss: 1.2234e-04
# Epoch 87/100
# 0s - loss: 1.1546e-04
# Epoch 88/100
# 0s - loss: 1.3728e-04
# Epoch 89/100
# 0s - loss: 1.2694e-04
# Epoch 90/100
# 0s - loss: 1.2383e-04
# Epoch 91/100
# 0s - loss: 1.2388e-04
# Epoch 92/100
# 0s - loss: 1.0233e-04
# Epoch 93/100
# 0s - loss: 9.9449e-05
# Epoch 94/100
# 0s - loss: 1.0992e-04
# Epoch 95/100
# 0s - loss: 9.8726e-05
# Epoch 96/100
# 0s - loss: 1.1323e-04
# Epoch 97/100
# 0s - loss: 1.1103e-04
# Epoch 98/100
# 0s - loss: 1.0923e-04
# Epoch 99/100
# 0s - loss: 1.1282e-04
# Epoch 100/100
# 0s - loss: 1.1339e-04

# %%
nn_plot_in_sample(nn, train_nn, bbox_loc=(1.45,1))

# %%
nn_scaled_forecast = nn_predict_series(nn, 
                                      last_obs_creator_nn(train_nn, lags_for_nn), 
                                      len(test))
nn_forecast = scaler_back(nn_scaled_forecast, scaler(train)[1], scaler(train)[2])

nn_plot_out_sample(nn_forecast, test, bbox_loc=(1.43,1))

# %%
errors_out_sample(test, nn_forecast)
# Out:
# {'MAE': 438.97673611111128, 'MSE': 282393.21164279513}

# %% [markdown]
# ### Hybrid

# %%
resids_arima = get_resids_arima(train, arima_model, d=2)
plt.plot(resids_arima)
plt.show()

# %%
scaled_resids_arima = scaler(resids_arima)[0]

lags_nn = 2

df_nn_resid = create_df_for_nn_residuals(scaled_resids_arima[1:], lags_nn)

def assemble_model(n_lags):
    model = Sequential()
    # Layers
    model.add(Dense(10, input_dim=n_lags, activation='sigmoid'))
    model.add(Dense(10, input_dim=10, activation='sigmoid'))
    model.add(Dropout(0.5))
    model.add(Dense(10, input_dim=10, activation='sigmoid'))
    model.add(Dense(1, input_dim=10))
    # Compilation
    model.compile(loss='mean_squared_error', optimizer='adam')
    return(model)

nn_resid = assemble_model(lags_nn)
nn_resid.fit(np.array(df_nn_resid.iloc[:, :-1]), 
       np.array(df_nn_resid.iloc[:, -1]), 
       nb_epoch=100, 
       verbose=2,
       batch_size=1)
# Out:
# Epoch 1/100
# 0s - loss: 0.1462
# Epoch 2/100
# 0s - loss: 0.0516
# Epoch 3/100
# 0s - loss: 0.0436
# Epoch 4/100
# 0s - loss: 0.0391
# Epoch 5/100
# 0s - loss: 0.0375
# Epoch 6/100
# 0s - loss: 0.0391
# Epoch 7/100
# 0s - loss: 0.0365
# Epoch 8/100
# 0s - loss: 0.0367
# Epoch 9/100
# 0s - loss: 0.0385
# Epoch 10/100
# 0s - loss: 0.0351
# Epoch 11/100
# 0s - loss: 0.0342
# Epoch 12/100
# 0s - loss: 0.0348
# Epoch 13/100
# 0s - loss: 0.0326
# Epoch 14/100
# 0s - loss: 0.0320
# Epoch 15/100
# 0s - loss: 0.0303
# Epoch 16/100
# 0s - loss: 0.0282
# Epoch 17/100
# 0s - loss: 0.0238
# Epoch 18/100
# 0s - loss: 0.0230
# Epoch 19/100
# 0s - loss: 0.0215
# Epoch 20/100
# 0s - loss: 0.0180
# Epoch 21/100
# 0s - loss: 0.0151
# Epoch 22/100
# 0s - loss: 0.0158
# Epoch 23/100
# 0s - loss: 0.0151
# Epoch 24/100
# 0s - loss: 0.0165
# Epoch 25/100
# 0s - loss: 0.0137
# Epoch 26/100
# 0s - loss: 0.0166
# Epoch 27/100
# 0s - loss: 0.0158
# Epoch 28/100
# 0s - loss: 0.0115
# Epoch 29/100
# 0s - loss: 0.0123
# Epoch 30/100
# 0s - loss: 0.0143
# Epoch 31/100
# 0s - loss: 0.0132
# Epoch 32/100
# 0s - loss: 0.0140
# Epoch 33/100
# 0s - loss: 0.0115
# Epoch 34/100
# 0s - loss: 0.0120
# Epoch 35/100
# 0s - loss: 0.0144
# Epoch 36/100
# 0s - loss: 0.0129
# Epoch 37/100
# 0s - loss: 0.0140
# Epoch 38/100
# 0s - loss: 0.0109
# Epoch 39/100
# 0s - loss: 0.0127
# Epoch 40/100
# 0s - loss: 0.0113
# Epoch 41/100
# 0s - loss: 0.0119
# Epoch 42/100
# 0s - loss: 0.0126
# Epoch 43/100
# 0s - loss: 0.0120
# Epoch 44/100
# 0s - loss: 0.0117
# Epoch 45/100
# 0s - loss: 0.0127
# Epoch 46/100
# 0s - loss: 0.0099
# Epoch 47/100
# 0s - loss: 0.0110
# Epoch 48/100
# 0s - loss: 0.0111
# Epoch 49/100
# 0s - loss: 0.0103
# Epoch 50/100
# 0s - loss: 0.0104
# Epoch 51/100
# 0s - loss: 0.0107
# Epoch 52/100
# 0s - loss: 0.0098
# Epoch 53/100
# 0s - loss: 0.0129
# Epoch 54/100
# 0s - loss: 0.0126
# Epoch 55/100
# 0s - loss: 0.0108
# Epoch 56/100
# 0s - loss: 0.0106
# Epoch 57/100
# 0s - loss: 0.0106
# Epoch 58/100
# 0s - loss: 0.0094
# Epoch 59/100
# 0s - loss: 0.0102
# Epoch 60/100
# 0s - loss: 0.0110
# Epoch 61/100
# 0s - loss: 0.0121
# Epoch 62/100
# 0s - loss: 0.0090
# Epoch 63/100
# 0s - loss: 0.0110
# Epoch 64/100
# 0s - loss: 0.0111
# Epoch 65/100
# 0s - loss: 0.0103
# Epoch 66/100
# 0s - loss: 0.0104
# Epoch 67/100
# 0s - loss: 0.0101
# Epoch 68/100
# 0s - loss: 0.0104
# Epoch 69/100
# 0s - loss: 0.0109
# Epoch 70/100
# 0s - loss: 0.0102
# Epoch 71/100
# 0s - loss: 0.0096
# Epoch 72/100
# 0s - loss: 0.0104
# Epoch 73/100
# 0s - loss: 0.0087
# Epoch 74/100
# 0s - loss: 0.0090
# Epoch 75/100
# 0s - loss: 0.0094
# Epoch 76/100
# 0s - loss: 0.0096
# Epoch 77/100
# 0s - loss: 0.0096
# Epoch 78/100
# 0s - loss: 0.0093
# Epoch 79/100
# 0s - loss: 0.0100
# Epoch 80/100
# 0s - loss: 0.0097
# Epoch 81/100
# 0s - loss: 0.0096
# Epoch 82/100
# 0s - loss: 0.0103
# Epoch 83/100
# 0s - loss: 0.0107
# Epoch 84/100
# 0s - loss: 0.0085
# Epoch 85/100
# 0s - loss: 0.0104
# Epoch 86/100
# 0s - loss: 0.0084
# Epoch 87/100
# 0s - loss: 0.0098
# Epoch 88/100
# 0s - loss: 0.0101
# Epoch 89/100
# 0s - loss: 0.0118
# Epoch 90/100
# 0s - loss: 0.0088
# Epoch 91/100
# 0s - loss: 0.0081
# Epoch 92/100
# 0s - loss: 0.0080
# Epoch 93/100
# 0s - loss: 0.0089
# Epoch 94/100
# 0s - loss: 0.0103
# Epoch 95/100
# 0s - loss: 0.0097
# Epoch 96/100
# 0s - loss: 0.0087
# Epoch 97/100
# 0s - loss: 0.0081
# Epoch 98/100
# 0s - loss: 0.0075
# Epoch 99/100
# 0s - loss: 0.0107
# Epoch 100/100
# 0s - loss: 0.0090

# %%
plt.plot(np.array(df_nn_resid.iloc[:, -1]), label='Resid')
plt.plot(nn_resid.predict(np.array(df_nn_resid.iloc[:, :-1])), label='Forecast')
plt.legend(bbox_to_anchor=(1.36,1), loc='best')
plt.show()

# %%
nn_scaled_resid_forecast = nn_predict_series(nn_resid, 
                                      last_lags_resid_df_for_nn(resids_arima, test, lags_nn), 
                                      len(test))

nn_resids_forecast = scaler_back(nn_scaled_resid_forecast, scaler(resids_arima)[1], scaler(resids_arima)[2])

hybrid_forecast = hybrid_predict_series(forc_arima, nn_resids_forecast)

# %%
hybrid_plot_forecast(forc_arima, nn_resids_forecast, test)

# %%
errors_out_sample(test, hybrid_forecast)
# Out:
# {'MAE': 337.47834291490449, 'MSE': 125191.01710890055}

# %%
nn_resids_forecast
# Out:
# array([-153.45031738, -153.45031738, -145.62974548, -144.21218872,
#        -143.06770325, -142.63150024, -142.38508606, -142.26942444,
#        -142.20942688], dtype=float32)
